# %% [markdown]
# # Welcome!
# Below, we will learn to implement and train a policy to play atari-pong, using only the pixels as input. We will use convolutional neural nets, multiprocessing, and pytorch to implement and train our policy. Let's get started!
#
# (I strongly recommend you to try this notebook on the Udacity workspace first before running it locally on your desktop/laptop, as performance might suffer in different environments)

# %%
# install package for displaying animation
# !pip install JSAnimation

# !pip install gym[atari]

# custom utilies for displaying animation, collecting rollouts and more
import pong_utils

# %matplotlib inline

# check which device is being used. 
# I recommend disabling gpu until you've made sure that the code runs
device = pong_utils.device
print("Using device: ", device)
# Out:
# Requirement already satisfied: JSAnimation in c:\users\filip\anaconda3\envs\ml\lib\site-packages (0.1)
# Requirement already satisfied: gym[atari] in c:\workstation\software_projects\python\udacity_reinforcement_learning_course\gym (0.17.3)
# Requirement already satisfied: scipy in c:\users\filip\anaconda3\envs\ml\lib\site-packages (from gym[atari]) (1.3.1)
# Requirement already satisfied: numpy>=1.10.4 in c:\users\filip\anaconda3\envs\ml\lib\site-packages (from gym[atari]) (1.16.4)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in c:\users\filip\anaconda3\envs\ml\lib\site-packages (from gym[atari]) (1.5.0)
# Requirement already satisfied: Pillow<=7.2.0 in c:\users\filip\anaconda3\envs\ml\lib\site-packages (from gym[atari]) (5.2.0)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in c:\users\filip\anaconda3\envs\ml\lib\site-packages (from gym[atari]) (1.2.2)
# Requirement already satisfied: atari_py~=0.2.0 in c:\users\filip\anaconda3\envs\ml\lib\site-packages (from gym[atari]) (0.2.6)
# Requirement already satisfied: opencv-python>=3. in c:\users\filip\anaconda3\envs\ml\lib\site-packages (from gym[atari]) (4.1.2.30)
# Requirement already satisfied: future in c:\users\filip\anaconda3\envs\ml\lib\site-packages (from pyglet<=1.5.0,>=1.4.0->gym[atari]) (0.18.2)
# Requirement already satisfied: six in c:\users\filip\anaconda3\envs\ml\lib\site-packages (from atari_py~=0.2.0->gym[atari]) (1.12.0)
# Using device:  cuda:0

# %%
# render ai gym environment
import gym
import time

# PongDeterministic does not contain random frameskip
# so is faster to train than the vanilla Pong-v4 environment
env = gym.make('PongDeterministic-v4')

print("List of available actions: ", env.unwrapped.get_action_meanings())

# we will only use the actions 'RIGHTFIRE' = 4 and 'LEFTFIRE" = 5
# the 'FIRE' part ensures that the game starts again after losing a life
# the actions are hard-coded in pong_utils.py
# Out:
# List of available actions:  ['NOOP', 'FIRE', 'RIGHT', 'LEFT', 'RIGHTFIRE', 'LEFTFIRE']

# %% [markdown]
# # Preprocessing
# To speed up training, we can simplify the input by cropping the images and use every other pixel

# %%
import matplotlib
import matplotlib.pyplot as plt

# show what a preprocessed image looks like
env.reset()
_, _, _, _ = env.step(0)
# get a frame after 20 steps
for _ in range(20):
    frame, _, _, _ = env.step(1)

plt.subplot(1,2,1)
plt.imshow(frame)
plt.title('original image')

plt.subplot(1,2,2)
plt.title('preprocessed image')

# 80 x 80 black and white image
plt.imshow(pong_utils.preprocess_single(frame), cmap='Greys')
plt.show()

# %% [markdown]
# # Policy
#
# ## Exercise 1: Implement your policy
#
# Here, we define our policy. The input is the stack of two different frames (which captures the movement), and the output is a number $P_{\rm right}$, the probability of moving left. Note that $P_{\rm left}= 1-P_{\rm right}$

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# set up a convolutional neural net
# the output is the probability of moving right
# P(left) = 1 - P(right)
class Policy(nn.Module):

    def __init__(self):
        super(Policy, self).__init__()
        
        # 80x80 to outputsize x outputsize
        # outputsize = (inputsize - kernel_size + stride)/stride 
        # (round up if not an integer)

        self.convs = nn.Sequential(
            # 2x80x80
            nn.Conv2d(2, 8, kernel_size=3, bias=False),
            nn.BatchNorm2d(8),
            nn.LeakyReLU(),
            # 8x78x78
            nn.Conv2d(8, 12, kernel_size=4, stride=2, bias=False),
            nn.BatchNorm2d(12),
            nn.LeakyReLU(),
            # 12x36x36
            nn.Conv2d(12, 64, kernel_size=4, stride=2, bias=False),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(),
            # 64x16x16
            nn.MaxPool2d(2, 2),
            #64x8x8
            nn.Conv2d(64, 64, kernel_size=4, stride=2, bias=False),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(),
            #64x2x2
            nn.MaxPool2d(2, 2)
            #64x1x1
        )
        
        
        self.size=64
        
        self.fcs = nn.Sequential(
            nn.Linear(self.size, 32),
            # Pr(left) = 1.0 - Pr(right)
            nn.Linear(32, 1)
        )
        
    def forward(self, x):
        x = self.convs(x)
        x = x.view(-1, self.size)
        return torch.sigmoid(self.fcs(x))

# use your own policy!
policy=Policy().to(device)


#policy=pong_utils.Policy().to(device)

# we use the adam optimizer with learning rate 2e-4
# optim.SGD is also possible
import torch.optim as optim
optimizer = optim.Adam(policy.parameters(), lr=1e-4)

# %% [markdown]
# # Game visualization
# pong_utils contain a play function given the environment and a policy. An optional preprocess function can be supplied. Here we define a function that plays a game and shows learning progress

# %%
#pong_utils.play(env, policy, time=100) 
# try to add the option "preprocess=pong_utils.preprocess_single"
# to see what the agent sees

# %% [markdown]
# # Rollout
# Before we start the training, we need to collect samples. To make things efficient we use parallelized environments to collect multiple examples at once

# %%
envs = pong_utils.parallelEnv('PongDeterministic-v4', n=4, seed=505)
# NOte: This uses multiprocesses as in a process there is something GIL which prevents tru thread usage
prob, state, action, reward = pong_utils.collect_trajectories(envs, policy, tmax=100)
# Out:
# old probs: [0.4720374 0.4720374 0.4720374 0.4720374]
# action: [4 5 5 5]
# old probs updated: [0.4720374  0.52796257 0.52796257 0.52796257]
# old probs: [0.48296046 0.48296046 0.48296046 0.48296046]
# action: [4 4 5 5]
# old probs updated: [0.48296046 0.48296046 0.51703954 0.51703954]
# old probs: [0.5587709 0.5587709 0.5587709 0.5587709]
# action: [5 4 5 5]
# old probs updated: [0.4412291 0.5587709 0.4412291 0.4412291]
# old probs: [0.43664342 0.43664342 0.43664342 0.43664342]
# action: [5 5 5 5]
# old probs updated: [0.5633566 0.5633566 0.5633566 0.5633566]
# old probs: [0.5188031 0.5188031 0.5188031 0.5188031]
# action: [4 5 4 4]
# old probs updated: [0.5188031  0.48119688 0.5188031  0.5188031 ]
# old probs: [0.45896077 0.45896077 0.45896077 0.45896077]
# action: [4 5 5 4]
# old probs updated: [0.45896077 0.5410392  0.5410392  0.45896077]
# old probs: [0.48405465 0.48405465 0.48405465 0.48405465]
# action: [4 5 5 5]
# old probs updated: [0.48405465 0.5159453  0.5159453  0.5159453 ]
# old probs: [0.50305164 0.50305164 0.50305164 0.50305164]
# action: [5 5 4 4]
# old probs updated: [0.49694836 0.49694836 0.50305164 0.50305164]
# old probs: [0.47690043 0.47690043 0.47690043 0.47690043]
# action: [5 4 5 5]
# old probs updated: [0.52309954 0.47690043 0.52309954 0.52309954]
# old probs: [0.48451036 0.48451036 0.48451036 0.48451036]
# action: [4 4 4 4]
# old probs updated: [0.48451036 0.48451036 0.48451036 0.48451036]
# old probs: [0.51518816 0.51518816 0.51518816 0.51518816]
# action: [4 4 4 4]
# old probs updated: [0.51518816 0.51518816 0.51518816 0.51518816]
# old probs: [0.49996978 0.49996978 0.49996978 0.49996978]
# action: [4 4 4 4]
# old probs updated: [0.49996978 0.49996978 0.49996978 0.49996978]
# old probs: [0.3994967 0.3994967 0.3994967 0.3994967]
# action: [5 4 4 5]
# old probs updated: [0.6005033 0.3994967 0.3994967 0.6005033]
# old probs: [0.43907553 0.43907553 0.43907553 0.43907553]
# action: [4 4 5 5]
# old probs updated: [0.43907553 0.43907553 0.5609245  0.5609245 ]
# old probs: [0.3801425 0.3801425 0.3801425 0.3801425]
# action: [5 4 4 5]
# old probs updated: [0.6198575 0.3801425 0.3801425 0.6198575]
# old probs: [0.43275335 0.43275335 0.43275335 0.43275335]
# action: [5 4 4 4]
# old probs updated: [0.5672467  0.43275335 0.43275335 0.43275335]
# old probs: [0.44294882 0.44294882 0.44294882 0.44294882]
# action: [4 4 4 5]
# old probs updated: [0.44294882 0.44294882 0.44294882 0.5570512 ]
# old probs: [0.4185816 0.4185816 0.4185816 0.4185816]
# action: [4 5 4 5]
# old probs updated: [0.4185816 0.5814184 0.4185816 0.5814184]
# old probs: [0.48641568 0.48641568 0.48641568 0.48641568]
# action: [5 5 4 4]
# old probs updated: [0.5135843  0.5135843  0.48641568 0.48641568]
# old probs: [0.34568015 0.34568015 0.34568015 0.34568015]
# action: [5 4 4 4]
# old probs updated: [0.6543199  0.34568015 0.34568015 0.34568015]
# old probs: [0.39974833 0.39974833 0.39974833 0.39974833]
# action: [5 5 5 4]
# old probs updated: [0.6002517  0.6002517  0.6002517  0.39974833]
# old probs: [0.40513995 0.40513995 0.40513995 0.40513995]
# action: [5 4 4 5]
# old probs updated: [0.5948601  0.40513995 0.40513995 0.5948601 ]
# old probs: [0.49665457 0.49665457 0.49665457 0.49665457]
# action: [4 4 5 5]
# old probs updated: [0.49665457 0.49665457 0.50334543 0.50334543]
# old probs: [0.40151566 0.40151566 0.40151566 0.40151566]
# action: [5 5 4 5]
# old probs updated: [0.59848434 0.59848434 0.40151566 0.59848434]
# old probs: [0.4478595 0.4478595 0.4478595 0.4478595]
# action: [5 5 5 4]
# old probs updated: [0.5521405 0.5521405 0.5521405 0.4478595]
# old probs: [0.30254006 0.30254006 0.30254006 0.30254006]
# action: [5 4 5 4]
# old probs updated: [0.69745994 0.30254006 0.69745994 0.30254006]
# old probs: [0.46172252 0.46172252 0.46172252 0.46172252]
# action: [5 4 4 5]
# old probs updated: [0.5382775  0.46172252 0.46172252 0.5382775 ]
# old probs: [0.41141778 0.41141778 0.41141778 0.49938843]
# action: [5 5 4 5]
# old probs updated: [0.5885822  0.5885822  0.41141778 0.50061154]
# old probs: [0.36433998 0.36433998 0.36433998 0.4764102 ]
# action: [4 5 5 4]
# old probs updated: [0.36433998 0.63566005 0.63566005 0.4764102 ]
# old probs: [0.40556377 0.40556377 0.40556377 0.49146104]
# action: [5 4 4 5]
# old probs updated: [0.5944362  0.40556377 0.40556377 0.50853896]
# old probs: [0.41842476 0.41842476 0.41842476 0.49480188]
# action: [5 4 5 4]
# old probs updated: [0.5815753  0.41842476 0.5815753  0.49480188]
# old probs: [0.4403293  0.4403293  0.4403293  0.48753572]
# action: [5 5 5 4]
# old probs updated: [0.5596707  0.5596707  0.5596707  0.48753572]
# old probs: [0.34739313 0.34739313 0.34739313 0.28719282]
# action: [5 5 5 5]
# old probs updated: [0.65260684 0.65260684 0.65260684 0.7128072 ]
# old probs: [0.38339698 0.38339698 0.38339698 0.43697655]
# action: [5 5 4 4]
# old probs updated: [0.616603   0.616603   0.38339698 0.43697655]
# old probs: [0.39575115 0.39575115 0.39575115 0.23519756]
# action: [5 5 5 5]
# old probs updated: [0.6042489  0.6042489  0.6042489  0.76480246]
# old probs: [0.328507  0.328507  0.328507  0.4624718]
# action: [5 5 5 5]
# old probs updated: [0.671493   0.671493   0.671493   0.53752816]
# old probs: [0.31618744 0.31618744 0.31618744 0.54519725]
# action: [4 4 5 5]
# old probs updated: [0.31618744 0.31618744 0.68381256 0.45480275]
# old probs: [0.491147   0.491147   0.491147   0.44372535]
# action: [5 5 4 5]
# old probs updated: [0.50885296 0.50885296 0.491147   0.55627465]
# old probs: [0.49665982 0.49665982 0.49665982 0.44315314]
# action: [4 5 5 4]
# old probs updated: [0.49665982 0.5033402  0.5033402  0.44315314]
# old probs: [0.5011784  0.5011784  0.5011784  0.60739595]
# action: [4 5 4 5]
# old probs updated: [0.5011784  0.49882162 0.5011784  0.39260405]
# old probs: [0.493012   0.493012   0.493012   0.51056975]
# action: [4 5 5 4]
# old probs updated: [0.493012   0.506988   0.506988   0.51056975]
# old probs: [0.4793733  0.4793733  0.4793733  0.47030413]
# action: [5 5 4 4]
# old probs updated: [0.52062666 0.52062666 0.4793733  0.47030413]
# old probs: [0.49166164 0.49166164 0.49166164 0.34289846]
# action: [5 5 4 5]
# old probs updated: [0.50833833 0.50833833 0.49166164 0.6571015 ]
# old probs: [0.4893839  0.4893839  0.4893839  0.35335547]
# action: [4 4 4 5]
# old probs updated: [0.4893839  0.4893839  0.4893839  0.64664453]
# old probs: [0.48368067 0.48368067 0.48368067 0.32048404]
# action: [5 5 5 5]
# old probs updated: [0.51631933 0.51631933 0.51631933 0.67951596]
# old probs: [0.48578876 0.48578876 0.48578876 0.343164  ]
# action: [4 4 5 5]
# old probs updated: [0.48578876 0.48578876 0.51421124 0.65683603]
# old probs: [0.4866544 0.4866544 0.4866544 0.4312267]
# action: [5 5 5 4]
# old probs updated: [0.5133456 0.5133456 0.5133456 0.4312267]
# old probs: [0.48425007 0.48425007 0.48425007 0.5613132 ]
# action: [5 4 5 5]
# old probs updated: [0.51574993 0.48425007 0.51574993 0.4386868 ]
# old probs: [0.36868462 0.36868462 0.36868462 0.6586496 ]
# action: [5 5 5 4]
# old probs updated: [0.63131535 0.63131535 0.63131535 0.6586496 ]
# old probs: [0.33465266 0.33465266 0.33465266 0.5520047 ]
# action: [5 5 4 5]
# old probs updated: [0.66534734 0.66534734 0.33465266 0.4479953 ]
# old probs: [0.41962048 0.41962048 0.41962048 0.3825809 ]
# action: [5 4 5 4]
# old probs updated: [0.5803795  0.41962048 0.5803795  0.3825809 ]
# old probs: [0.5453457  0.5453457  0.5453457  0.33629367]
# action: [4 5 4 5]
# old probs updated: [0.5453457  0.45465428 0.5453457  0.6637063 ]
# old probs: [0.368066   0.368066   0.368066   0.53811365]
# action: [4 5 5 5]
# old probs updated: [0.368066   0.631934   0.631934   0.46188635]
# old probs: [0.32266688 0.32266688 0.32266688 0.43898034]
# action: [4 4 4 4]
# old probs updated: [0.32266688 0.32266688 0.32266688 0.43898034]
# old probs: [0.5018388  0.5018388  0.5018388  0.49012157]
# action: [4 5 5 5]
# old probs updated: [0.5018388 0.4981612 0.4981612 0.5098784]
# old probs: [0.46285304 0.46285304 0.46285304 0.30032626]
# action: [5 4 4 5]
# old probs updated: [0.5371469  0.46285304 0.46285304 0.6996738 ]
# old probs: [0.4767844  0.4767844  0.4767844  0.31192923]
# action: [4 5 5 4]
# old probs updated: [0.4767844  0.5232156  0.5232156  0.31192923]
# old probs: [0.49537337 0.49537337 0.49537337 0.3828272 ]
# action: [4 5 4 5]
# old probs updated: [0.49537337 0.50462663 0.49537337 0.61717284]
# old probs: [0.4933503  0.4933503  0.4933503  0.47135648]
# action: [5 5 5 4]
# old probs updated: [0.50664973 0.50664973 0.50664973 0.47135648]
# old probs: [0.49594265 0.49594265 0.49594265 0.49594265]
# action: [4 4 5 5]
# old probs updated: [0.49594265 0.49594265 0.50405735 0.50405735]
# old probs: [0.4905099 0.4905099 0.4905099 0.4905099]
# action: [4 5 5 4]
# old probs updated: [0.4905099  0.50949013 0.50949013 0.4905099 ]
# old probs: [0.48931426 0.48931426 0.48931426 0.48931426]
# action: [4 5 5 5]
# old probs updated: [0.48931426 0.51068574 0.51068574 0.51068574]
# old probs: [0.48122674 0.48122674 0.48122674 0.48122674]
# action: [4 5 4 5]
# old probs updated: [0.48122674 0.51877326 0.48122674 0.51877326]
# old probs: [0.5040767 0.5040767 0.5040767 0.5040767]
# action: [5 4 4 4]
# old probs updated: [0.49592328 0.5040767  0.5040767  0.5040767 ]
# old probs: [0.4907    0.4907    0.5739865 0.4438739]
# action: [5 5 4 4]
# old probs updated: [0.5093    0.5093    0.5739865 0.4438739]
# old probs: [0.43062237 0.49096745 0.29323283 0.43736115]
# action: [5 5 5 4]
# old probs updated: [0.56937766 0.50903255 0.7067672  0.43736115]
# old probs: [0.3868372 0.4785986 0.5590676 0.3607659]
# action: [4 5 5 4]
# old probs updated: [0.3868372 0.5214014 0.4409324 0.3607659]
# old probs: [0.39969307 0.48616922 0.38972878 0.5616975 ]
# action: [4 5 5 4]
# old probs updated: [0.39969307 0.5138308  0.6102712  0.5616975 ]
# old probs: [0.34180275 0.48280668 0.5769708  0.5141018 ]
# action: [4 4 4 4]
# old probs updated: [0.34180275 0.48280668 0.5769708  0.5141018 ]
# old probs: [0.5253524  0.4767707  0.4135247  0.48695308]
# action: [5 5 5 4]
# old probs updated: [0.47464758 0.5232293  0.5864753  0.48695308]
# old probs: [0.28030625 0.4130759  0.4960568  0.50290984]
# action: [4 4 4 5]
# old probs updated: [0.28030625 0.4130759  0.4960568  0.49709016]
# old probs: [0.25710288 0.50994766 0.5491007  0.45737135]
# action: [5 5 5 5]
# old probs updated: [0.74289715 0.49005234 0.4508993  0.54262865]
# old probs: [0.4744372  0.35054988 0.48655233 0.5042854 ]
# action: [4 5 4 4]
# old probs updated: [0.4744372  0.6494501  0.48655233 0.5042854 ]
# old probs: [0.5087486  0.40946084 0.48682708 0.49758846]
# action: [4 5 5 5]
# old probs updated: [0.5087486  0.59053916 0.5131729  0.50241154]
# old probs: [0.4921828  0.45746115 0.4921828  0.3940214 ]
# action: [4 5 5 5]
# old probs updated: [0.4921828 0.5425389 0.5078172 0.6059786]
# old probs: [0.4893186  0.49406594 0.4893186  0.33587837]
# action: [4 4 5 5]
# old probs updated: [0.4893186  0.49406594 0.5106814  0.6641216 ]
# old probs: [0.47681662 0.5096826  0.50850385 0.47310758]
# action: [4 5 5 5]
# old probs updated: [0.47681662 0.4903174  0.49149615 0.5268924 ]
# old probs: [0.49006385 0.5119913  0.40613726 0.33163232]
# action: [5 4 4 4]
# old probs updated: [0.50993615 0.5119913  0.40613726 0.33163232]
# old probs: [0.48998877 0.502684   0.414225   0.46471038]
# action: [4 5 5 4]
# old probs updated: [0.48998877 0.497316   0.585775   0.46471038]
# old probs: [0.48307326 0.44850186 0.37283123 0.4496073 ]
# action: [5 5 5 5]
# old probs updated: [0.51692677 0.5514982  0.6271688  0.5503927 ]
# old probs: [0.48026603 0.48026603 0.3737928  0.50055003]
# action: [5 5 4 4]
# old probs updated: [0.51973397 0.51973397 0.3737928  0.50055003]
# old probs: [0.4919197  0.4919197  0.38886297 0.39404923]
# action: [4 5 4 4]
# old probs updated: [0.4919197  0.5080803  0.38886297 0.39404923]
# old probs: [0.48947415 0.48947415 0.50319076 0.4943924 ]
# action: [4 5 5 5]
# old probs updated: [0.48947415 0.5105258  0.49680924 0.5056076 ]
# old probs: [0.32431483 0.48886058 0.5787654  0.43663713]
# action: [4 5 5 5]
# old probs updated: [0.32431483 0.5111394  0.4212346  0.56336284]
# old probs: [0.24980807 0.48579675 0.57028264 0.47782153]
# action: [4 4 4 4]
# old probs updated: [0.24980807 0.48579675 0.57028264 0.47782153]
# old probs: [0.43019155 0.27185905 0.44829053 0.49312606]
# action: [5 4 5 5]
# old probs updated: [0.5698085  0.27185905 0.5517095  0.50687397]
# old probs: [0.5521654  0.29315445 0.43496943 0.49113905]
# action: [5 5 5 5]
# old probs updated: [0.4478346  0.7068455  0.5650306  0.50886095]
# old probs: [0.36178502 0.47918847 0.57562226 0.48124674]
# action: [5 4 5 5]
# old probs updated: [0.63821495 0.47918847 0.42437774 0.5187533 ]
# old probs: [0.27853632 0.37857404 0.41161942 0.48368004]
# action: [5 5 5 5]
# old probs updated: [0.7214637 0.621426  0.5883806 0.51632  ]
# old probs: [0.46945128 0.5434209  0.4699636  0.48959792]
# action: [5 5 4 5]
# old probs updated: [0.5305487 0.4565791 0.4699636 0.5104021]
# old probs: [0.44818372 0.38840553 0.28365108 0.49464747]
# action: [5 4 5 4]
# old probs updated: [0.5518163  0.38840553 0.7163489  0.49464747]
# old probs: [0.48435086 0.51544344 0.3203746  0.47671786]
# action: [5 5 4 4]
# old probs updated: [0.51564914 0.48455656 0.3203746  0.47671786]
# old probs: [0.4963928  0.52464986 0.38457048 0.25765318]
# action: [4 4 5 5]
# old probs updated: [0.4963928  0.52464986 0.6154295  0.7423468 ]
# old probs: [0.48494557 0.4964026  0.46782503 0.44668996]
# action: [5 5 5 4]
# old probs updated: [0.51505446 0.5035974  0.53217494 0.44668996]
# old probs: [0.49004385 0.4790477  0.49004385 0.3979724 ]
# action: [4 4 4 4]
# old probs updated: [0.49004385 0.4790477  0.49004385 0.3979724 ]
# old probs: [0.48275658 0.44977385 0.48275658 0.45220548]
# action: [4 4 5 5]
# old probs updated: [0.48275658 0.44977385 0.5172434  0.5477945 ]
# old probs: [0.4827435 0.4827435 0.4827435 0.3961077]
# action: [4 4 4 4]
# old probs updated: [0.4827435 0.4827435 0.4827435 0.3961077]
# old probs: [0.48000425 0.48000425 0.48000425 0.45945802]
# action: [5 4 4 4]
# old probs updated: [0.51999575 0.48000425 0.48000425 0.45945802]
# old probs: [0.48889208 0.48889208 0.48889208 0.55010885]
# action: [5 5 4 4]
# old probs updated: [0.5111079  0.5111079  0.48889208 0.55010885]
# old probs: [0.48149446 0.48149446 0.3896967  0.5233769 ]
# action: [5 4 4 4]
# old probs updated: [0.5185056  0.48149446 0.3896967  0.5233769 ]

# %%
print(prob[:5])
# Out:
# [array([0.4720374 , 0.52796257, 0.52796257, 0.52796257], dtype=float32), array([0.48296046, 0.48296046, 0.51703954, 0.51703954], dtype=float32), array([0.4412291, 0.5587709, 0.4412291, 0.4412291], dtype=float32), array([0.5633566, 0.5633566, 0.5633566, 0.5633566], dtype=float32), array([0.5188031 , 0.48119688, 0.5188031 , 0.5188031 ], dtype=float32)]

# %% [markdown]
# # Function Definitions
# Here you will define key functions for training.
#
# ## Exercise 2: write your own function for training
# (this is the same as policy_loss except the negative sign)
#
# ### REINFORCE
# you have two choices (usually it's useful to divide by the time since we've normalized our rewards and the time of each trajectory is fixed)
#
# 1. $\frac{1}{T}\sum^T_t R_{t}^{\rm future}\log(\pi_{\theta'}(a_t|s_t))$
# 2. $\frac{1}{T}\sum^T_t R_{t}^{\rm future}\frac{\pi_{\theta'}(a_t|s_t)}{\pi_{\theta}(a_t|s_t)}$ where $\theta'=\theta$ and make sure that the no_grad is enabled when performing the division

# %%
def surrogate(policy, old_probs, states, actions, rewards, gamma = 0.995, beta=0.01):
    
    old_probs = torch.tensor(old_probs, dtype=torch.float32, device=device)
    actions = torch.tensor(actions, dtype=torch.int8, device=device)
    
    # Discount them
    Gt = torch.tensor([ (gamma ** idx) * R for idx, R in enumerate(rewards) ], dtype=torch.float32, device=device)
    mu = torch.mean(Gt)
    std = torch.std(Gt)
    Gt -= mu
    Gt /= std

    # convert states to policy (or probability)
    new_probs = pong_utils.states_to_prob(policy, states)
    new_probs = torch.where(actions == pong_utils.RIGHT, new_probs, 1.0 - new_probs)
    
    prob_ratio = None
    with torch.no_grad():
        prob_ratio = torch.div(new_probs, old_probs)

    # include a regularization term
    # this steers new_policy towards 0.5
    # which prevents policy to become exactly 0 or 1
    # this helps with exploration
    # add in 1.e-10 to avoid log(0) which gives nan
    entropy = -(new_probs * torch.log(old_probs + 1.e-10) + (1.0 - new_probs) * torch.log(1.0 - old_probs + 1.e-10))

    return torch.mean(beta * entropy + Gt * prob_ratio)

Lsur= surrogate(policy, prob, state, action, reward)
print(Lsur)

Lsur= pong_utils.surrogate(policy, prob, state, action, reward)
print(Lsur)
# Out:
# new probs: tensor([[0.4933, 0.4933, 0.4933, 0.4933],
#         [0.4933, 0.4933, 0.4933, 0.4933],
#         [0.6635, 0.6635, 0.6635, 0.6635],
#         [0.4080, 0.4080, 0.4080, 0.4080],
#         [0.5243, 0.5243, 0.5243, 0.5243],
#         [0.4392, 0.4392, 0.4392, 0.4392],
#         [0.4789, 0.4789, 0.4789, 0.4789],
#         [0.4933, 0.4933, 0.4933, 0.4933],
#         [0.4933, 0.4933, 0.4933, 0.4933],
#         [0.4933, 0.4933, 0.4933, 0.4933],
#         [0.4933, 0.4933, 0.4933, 0.4933],
#         [0.4933, 0.4933, 0.4933, 0.4933],
#         [0.3139, 0.3139, 0.3139, 0.3139],
#         [0.3943, 0.3943, 0.3943, 0.3943],
#         [0.3024, 0.3024, 0.3024, 0.3024],
#         [0.4848, 0.4848, 0.4848, 0.4848],
#         [0.4202, 0.4202, 0.4202, 0.4202],
#         [0.3875, 0.3875, 0.3875, 0.3875],
#         [0.4072, 0.4072, 0.4072, 0.4072],
#         [0.4163, 0.4163, 0.4163, 0.4163],
#         [0.4864, 0.4864, 0.4864, 0.4864],
#         [0.3812, 0.3812, 0.3812, 0.3812],
#         [0.5140, 0.5140, 0.5140, 0.5140],
#         [0.3807, 0.3807, 0.3807, 0.3807],
#         [0.4090, 0.4090, 0.4090, 0.4090],
#         [0.2999, 0.2999, 0.2999, 0.2999],
#         [0.4829, 0.4829, 0.4829, 0.4829],
#         [0.4500, 0.4500, 0.4500, 0.4933],
#         [0.3923, 0.3923, 0.3923, 0.4933],
#         [0.4308, 0.4308, 0.4308, 0.4933],
#         [0.4061, 0.4061, 0.4061, 0.4933],
#         [0.4828, 0.4828, 0.4828, 0.4933],
#         [0.3898, 0.3898, 0.3898, 0.3118],
#         [0.4910, 0.4910, 0.4910, 0.5104],
#         [0.4811, 0.4811, 0.4811, 0.3886],
#         [0.2707, 0.2707, 0.2707, 0.4669],
#         [0.2172, 0.2172, 0.2172, 0.4840],
#         [0.4584, 0.4584, 0.4584, 0.4443],
#         [0.4907, 0.4907, 0.4907, 0.4741],
#         [0.4933, 0.4933, 0.4933, 0.5354],
#         [0.4933, 0.4933, 0.4933, 0.4646],
#         [0.4933, 0.4933, 0.4933, 0.4550],
#         [0.4933, 0.4933, 0.4933, 0.4745],
#         [0.4933, 0.4933, 0.4933, 0.4595],
#         [0.4933, 0.4933, 0.4933, 0.4819],
#         [0.4933, 0.4933, 0.4933, 0.3521],
#         [0.4933, 0.4933, 0.4933, 0.5284],
#         [0.4933, 0.4933, 0.4933, 0.5896],
#         [0.3993, 0.3993, 0.3993, 0.5659],
#         [0.3884, 0.3884, 0.3884, 0.6118],
#         [0.4974, 0.4974, 0.4974, 0.4958],
#         [0.5703, 0.5703, 0.5703, 0.3775],
#         [0.3001, 0.3001, 0.3001, 0.6271],
#         [0.2877, 0.2877, 0.2877, 0.4431],
#         [0.4366, 0.4366, 0.4366, 0.3725],
#         [0.4559, 0.4559, 0.4559, 0.3022],
#         [0.4820, 0.4820, 0.4820, 0.2843],
#         [0.4933, 0.4933, 0.4933, 0.3663],
#         [0.4933, 0.4933, 0.4933, 0.4780],
#         [0.4933, 0.4933, 0.4933, 0.4933],
#         [0.4933, 0.4933, 0.4933, 0.4933],
#         [0.4933, 0.4933, 0.4933, 0.4933],
#         [0.4933, 0.4933, 0.4933, 0.4933],
#         [0.4933, 0.4933, 0.4933, 0.4933],
#         [0.4933, 0.4933, 0.5271, 0.4390],
#         [0.4500, 0.4933, 0.3509, 0.4716],
#         [0.3923, 0.4933, 0.6107, 0.4054],
#         [0.4308, 0.4933, 0.4379, 0.5947],
#         [0.4061, 0.4933, 0.5525, 0.5247],
#         [0.4828, 0.4933, 0.4443, 0.5146],
#         [0.2707, 0.3778, 0.4741, 0.4914],
#         [0.2172, 0.4702, 0.5354, 0.4584],
#         [0.4584, 0.2675, 0.4646, 0.4917],
#         [0.4907, 0.4327, 0.4865, 0.4933],
#         [0.4933, 0.4083, 0.4933, 0.3168],
#         [0.4933, 0.5298, 0.4933, 0.3129],
#         [0.4933, 0.4977, 0.4714, 0.4537],
#         [0.4933, 0.5214, 0.4745, 0.3822],
#         [0.4933, 0.4977, 0.4595, 0.5276],
#         [0.4933, 0.4569, 0.4819, 0.4938],
#         [0.4933, 0.4933, 0.3521, 0.4910],
#         [0.4933, 0.4933, 0.5284, 0.4433],
#         [0.4933, 0.4933, 0.5896, 0.5058],
#         [0.3993, 0.4933, 0.5659, 0.4791],
#         [0.3884, 0.4933, 0.6118, 0.4917],
#         [0.4974, 0.3175, 0.4958, 0.4933],
#         [0.5703, 0.3185, 0.3775, 0.4933],
#         [0.3001, 0.5020, 0.6271, 0.4933],
#         [0.2877, 0.4237, 0.4431, 0.4933],
#         [0.4366, 0.5273, 0.3725, 0.4933],
#         [0.4559, 0.4205, 0.3022, 0.4933],
#         [0.4820, 0.5106, 0.2843, 0.4136],
#         [0.4933, 0.4763, 0.3663, 0.1904],
#         [0.4933, 0.4936, 0.4780, 0.4318],
#         [0.4933, 0.4753, 0.4933, 0.3407],
#         [0.4933, 0.4817, 0.4933, 0.4630],
#         [0.4933, 0.4933, 0.4933, 0.4232],
#         [0.4933, 0.4933, 0.4933, 0.4777],
#         [0.4933, 0.4933, 0.4933, 0.4939],
#         [0.4933, 0.4933, 0.4390, 0.5003]], device='cuda:0',
#        grad_fn=<ViewBackward>)
# new probs updated: tensor([[0.4933, 0.5067, 0.5067, 0.5067],
#         [0.4933, 0.4933, 0.5067, 0.5067],
#         [0.3365, 0.6635, 0.3365, 0.3365],
#         [0.5920, 0.5920, 0.5920, 0.5920],
#         [0.5243, 0.4757, 0.5243, 0.5243],
#         [0.4392, 0.5608, 0.5608, 0.4392],
#         [0.4789, 0.5211, 0.5211, 0.5211],
#         [0.5067, 0.5067, 0.4933, 0.4933],
#         [0.5067, 0.4933, 0.5067, 0.5067],
#         [0.4933, 0.4933, 0.4933, 0.4933],
#         [0.4933, 0.4933, 0.4933, 0.4933],
#         [0.4933, 0.4933, 0.4933, 0.4933],
#         [0.6861, 0.3139, 0.3139, 0.6861],
#         [0.3943, 0.3943, 0.6057, 0.6057],
#         [0.6976, 0.3024, 0.3024, 0.6976],
#         [0.5152, 0.4848, 0.4848, 0.4848],
#         [0.4202, 0.4202, 0.4202, 0.5798],
#         [0.3875, 0.6125, 0.3875, 0.6125],
#         [0.5928, 0.5928, 0.4072, 0.4072],
#         [0.5837, 0.4163, 0.4163, 0.4163],
#         [0.5136, 0.5136, 0.5136, 0.4864],
#         [0.6188, 0.3812, 0.3812, 0.6188],
#         [0.5140, 0.5140, 0.4860, 0.4860],
#         [0.6193, 0.6193, 0.3807, 0.6193],
#         [0.5910, 0.5910, 0.5910, 0.4090],
#         [0.7001, 0.2999, 0.7001, 0.2999],
#         [0.5171, 0.4829, 0.4829, 0.5171],
#         [0.5500, 0.5500, 0.4500, 0.5067],
#         [0.3923, 0.6077, 0.6077, 0.4933],
#         [0.5692, 0.4308, 0.4308, 0.5067],
#         [0.5939, 0.4061, 0.5939, 0.4933],
#         [0.5172, 0.5172, 0.5172, 0.4933],
#         [0.6102, 0.6102, 0.6102, 0.6882],
#         [0.5090, 0.5090, 0.4910, 0.5104],
#         [0.5189, 0.5189, 0.5189, 0.6114],
#         [0.7293, 0.7293, 0.7293, 0.5331],
#         [0.2172, 0.2172, 0.7828, 0.5160],
#         [0.5416, 0.5416, 0.4584, 0.5557],
#         [0.4907, 0.5093, 0.5093, 0.4741],
#         [0.4933, 0.5067, 0.4933, 0.4646],
#         [0.4933, 0.5067, 0.5067, 0.4646],
#         [0.5067, 0.5067, 0.4933, 0.4550],
#         [0.5067, 0.5067, 0.4933, 0.5255],
#         [0.4933, 0.4933, 0.4933, 0.5405],
#         [0.5067, 0.5067, 0.5067, 0.5181],
#         [0.4933, 0.4933, 0.5067, 0.6479],
#         [0.5067, 0.5067, 0.5067, 0.5284],
#         [0.5067, 0.4933, 0.5067, 0.4104],
#         [0.6007, 0.6007, 0.6007, 0.5659],
#         [0.6116, 0.6116, 0.3884, 0.3882],
#         [0.5026, 0.4974, 0.5026, 0.4958],
#         [0.5703, 0.4297, 0.5703, 0.6225],
#         [0.3001, 0.6999, 0.6999, 0.3729],
#         [0.2877, 0.2877, 0.2877, 0.4431],
#         [0.4366, 0.5634, 0.5634, 0.6275],
#         [0.5441, 0.4559, 0.4559, 0.6978],
#         [0.4820, 0.5180, 0.5180, 0.2843],
#         [0.4933, 0.5067, 0.4933, 0.6337],
#         [0.5067, 0.5067, 0.5067, 0.4780],
#         [0.4933, 0.4933, 0.5067, 0.5067],
#         [0.4933, 0.5067, 0.5067, 0.4933],
#         [0.4933, 0.5067, 0.5067, 0.5067],
#         [0.4933, 0.5067, 0.4933, 0.5067],
#         [0.5067, 0.4933, 0.4933, 0.4933],
#         [0.5067, 0.5067, 0.5271, 0.4390],
#         [0.5500, 0.5067, 0.6491, 0.4716],
#         [0.3923, 0.5067, 0.3893, 0.4054],
#         [0.4308, 0.5067, 0.5621, 0.5947],
#         [0.4061, 0.4933, 0.5525, 0.5247],
#         [0.5172, 0.5067, 0.5557, 0.5146],
#         [0.2707, 0.3778, 0.4741, 0.5086],
#         [0.7828, 0.5298, 0.4646, 0.5416],
#         [0.4584, 0.7325, 0.4646, 0.4917],
#         [0.4907, 0.5673, 0.5135, 0.5067],
#         [0.4933, 0.5917, 0.5067, 0.6832],
#         [0.4933, 0.5298, 0.5067, 0.6871],
#         [0.4933, 0.5023, 0.5286, 0.5463],
#         [0.5067, 0.5214, 0.4745, 0.3822],
#         [0.4933, 0.5023, 0.5405, 0.5276],
#         [0.5067, 0.5431, 0.5181, 0.5062],
#         [0.5067, 0.5067, 0.3521, 0.4910],
#         [0.4933, 0.5067, 0.5284, 0.4433],
#         [0.4933, 0.5067, 0.4104, 0.4942],
#         [0.3993, 0.5067, 0.4341, 0.5209],
#         [0.3884, 0.4933, 0.6118, 0.4917],
#         [0.5026, 0.3175, 0.5042, 0.5067],
#         [0.4297, 0.6815, 0.6225, 0.5067],
#         [0.6999, 0.5020, 0.3729, 0.5067],
#         [0.7123, 0.5763, 0.5569, 0.5067],
#         [0.5634, 0.4727, 0.3725, 0.5067],
#         [0.5441, 0.4205, 0.6978, 0.4933],
#         [0.5180, 0.4894, 0.2843, 0.4136],
#         [0.4933, 0.4763, 0.6337, 0.8096],
#         [0.5067, 0.5064, 0.5220, 0.4318],
#         [0.4933, 0.4753, 0.4933, 0.3407],
#         [0.4933, 0.4817, 0.5067, 0.5370],
#         [0.4933, 0.4933, 0.4933, 0.4232],
#         [0.5067, 0.4933, 0.4933, 0.4777],
#         [0.5067, 0.5067, 0.4933, 0.4939],
#         [0.5067, 0.4933, 0.4390, 0.5003]], device='cuda:0',
#        grad_fn=<SWhereBackward>)
# tensor(0.0024, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)

# %% [markdown]
# # Training
# We are now ready to train our policy!
# WARNING: make sure to turn on GPU, which also enables multicore processing. It may take up to 45 minutes even with GPU enabled, otherwise it will take much longer!

# %%
from parallelEnv import parallelEnv
import numpy as np
# WARNING: running through all 800 episodes will take 30-45 minutes

# training loop max iterations
episode = 500
# episode = 800

# widget bar to display progress
# !pip install progressbar
import progressbar as pb
widget = ['training loop: ', pb.Percentage(), ' ', 
          pb.Bar(), ' ', pb.ETA() ]
timer = pb.ProgressBar(widgets=widget, maxval=episode).start()

# initialize environment
envs = parallelEnv('PongDeterministic-v4', n=8, seed=1234)

discount_rate = .99
beta = .01
tmax = 320

# keep track of progress
mean_rewards = []

for e in range(episode):

    # collect trajectories
    old_probs, states, actions, rewards = \
        pong_utils.collect_trajectories(envs, policy, tmax=tmax)
        
    total_rewards = np.sum(rewards, axis=0)

    # this is the SOLUTION!
    # use your own surrogate function
    L = -surrogate(policy, old_probs, states, actions, rewards, beta=beta)
    
    #L = -pong_utils.surrogate(policy, old_probs, states, actions, rewards, beta=beta)
    
    optimizer.zero_grad()
    L.backward()
    optimizer.step()
    
    del L
        
    # the regulation term also reduces
    # this reduces exploration in later runs
    beta *= 0.995
    
    # get the average reward of the parallel environments
    mean_rewards.append(np.mean(total_rewards))
    
    # display some progress every 20 iterations
    if (e + 1) % 20 == 0:
        print("Episode: {0:d}, score: {1:f}".format(e + 1, np.mean(total_rewards)))
        print(total_rewards)
        
    # update progress widget bar
    timer.update(e + 1)
    
timer.finish()
# Out:
# training loop:   0% |                                          | ETA:  --:--:--
# Requirement already satisfied: progressbar in c:\users\filip\anaconda3\envs\ml\lib\site-packages (2.5)
# old probs: [0.47804046 0.47804046 0.47804046 0.47804046 0.47804046 0.47804046
#  0.47804046 0.47804046]
# action: [5 4 4 5 4 4 4 4]
# old probs updated: [0.52195954 0.47804046 0.47804046 0.52195954 0.47804046 0.47804046
#  0.47804046 0.47804046]
# old probs: [0.48659796 0.48659796 0.48659796 0.48659796 0.48659796 0.48659796
#  0.48659796 0.48659796]
# action: [5 5 4 5 5 5 4 5]
# old probs updated: [0.51340204 0.51340204 0.48659796 0.51340204 0.51340204 0.51340204
#  0.48659796 0.51340204]
# old probs: [0.55493826 0.55493826 0.55493826 0.55493826 0.55493826 0.55493826
#  0.55493826 0.55493826]
# action: [4 5 5 5 4 4 5 5]
# old probs updated: [0.55493826 0.44506174 0.44506174 0.44506174 0.55493826 0.55493826
#  0.44506174 0.44506174]
# old probs: [0.43742886 0.43742886 0.43742886 0.43742886 0.43742886 0.43742886
#  0.43742886 0.43742886]
# action: [5 4 5 4 5 4 5 5]
# old probs updated: [0.56257117 0.43742886 0.56257117 0.43742886 0.56257117 0.43742886
#  0.56257117 0.56257117]
# old probs: [0.52167934 0.52167934 0.52167934 0.52167934 0.52167934 0.52167934
#  0.52167934 0.52167934]
# action: [5 4 5 5 5 4 4 5]
# old probs updated: [0.47832066 0.52167934 0.47832066 0.47832066 0.47832066 0.52167934
#  0.52167934 0.47832066]
# old probs: [0.45603982 0.45603982 0.45603982 0.45603982 0.45603982 0.45603982
#  0.45603982 0.45603982]
# action: [5 4 4 4 4 4 5 5]
# old probs updated: [0.5439602  0.45603982 0.45603982 0.45603982 0.45603982 0.45603982
#  0.5439602  0.5439602 ]
# old probs: [0.48315236 0.48315236 0.48315236 0.48315236 0.48315236 0.48315236
#  0.48315236 0.48315236]
# action: [4 5 4 4 4 5 5 5]
# old probs updated: [0.48315236 0.5168476  0.48315236 0.48315236 0.48315236 0.5168476
#  0.5168476  0.5168476 ]
# old probs: [0.50338805 0.50338805 0.50338805 0.50338805 0.50338805 0.50338805
#  0.50338805 0.50338805]
# action: [5 5 5 5 5 4 5 4]
# old probs updated: [0.49661195 0.49661195 0.49661195 0.49661195 0.49661195 0.50338805
#  0.49661195 0.50338805]
# old probs: [0.47461778 0.47461778 0.47461778 0.47461778 0.47461778 0.47461778
#  0.47461778 0.47461778]
# action: [5 4 5 5 4 5 4 5]
# old probs updated: [0.5253822  0.47461778 0.5253822  0.5253822  0.47461778 0.5253822
#  0.47461778 0.5253822 ]
# old probs: [0.4866903 0.4866903 0.4866903 0.4866903 0.4866903 0.4866903 0.4866903
#  0.4866903]
# action: [4 5 5 5 5 5 5 4]
# old probs updated: [0.4866903 0.5133097 0.5133097 0.5133097 0.5133097 0.5133097 0.5133097
#  0.4866903]
# old probs: [0.5183387 0.5183387 0.5183387 0.5183387 0.5183387 0.5183387 0.5183387
#  0.5183387]
# action: [4 4 4 4 5 5 4 5]
# old probs updated: [0.5183387  0.5183387  0.5183387  0.5183387  0.48166132 0.48166132
#  0.5183387  0.48166132]
# old probs: [0.5014013 0.5014013 0.5014013 0.5014013 0.5014013 0.5014013 0.5014013
#  0.5014013]
# action: [4 4 5 4 4 4 5 5]
# old probs updated: [0.5014013 0.5014013 0.4985987 0.5014013 0.5014013 0.5014013 0.4985987
#  0.4985987]
# old probs: [0.40273657 0.40273657 0.40273657 0.40273657 0.40273657 0.40273657
#  0.40273657 0.40273657]
# action: [4 4 5 5 5 5 4 5]
# old probs updated: [0.40273657 0.40273657 0.59726346 0.59726346 0.59726346 0.59726346
#  0.40273657 0.59726346]
# old probs: [0.4395971 0.4395971 0.4395971 0.4395971 0.4395971 0.4395971 0.4395971
#  0.4395971]
# action: [4 4 4 5 5 5 4 4]
# old probs updated: [0.4395971  0.4395971  0.4395971  0.56040287 0.56040287 0.56040287
#  0.4395971  0.4395971 ]
# old probs: [0.37921658 0.37921658 0.37921658 0.37921658 0.37921658 0.37921658
#  0.37921658 0.37921658]
# action: [5 4 4 4 4 5 4 5]
# old probs updated: [0.62078345 0.37921658 0.37921658 0.37921658 0.37921658 0.62078345
#  0.37921658 0.62078345]
# old probs: [0.43302274 0.43302274 0.43302274 0.43302274 0.43302274 0.43302274
#  0.43302274 0.43302274]
# action: [5 5 5 5 5 5 5 4]
# old probs updated: [0.56697726 0.56697726 0.56697726 0.56697726 0.56697726 0.56697726
#  0.56697726 0.43302274]
# old probs: [0.44035807 0.44035807 0.44035807 0.44035807 0.44035807 0.44035807
#  0.44035807 0.44035807]
# action: [5 4 5 4 4 4 4 5]
# old probs updated: [0.55964196 0.44035807 0.55964196 0.44035807 0.44035807 0.44035807
#  0.44035807 0.55964196]
# old probs: [0.41651985 0.41651985 0.41651985 0.41651985 0.41651985 0.41651985
#  0.41651985 0.41651985]
# action: [4 5 5 5 5 4 5 4]
# old probs updated: [0.41651985 0.5834801  0.5834801  0.5834801  0.5834801  0.41651985
#  0.5834801  0.41651985]
# old probs: [0.48336655 0.48336655 0.48336655 0.48336655 0.48336655 0.48336655
#  0.48336655 0.48336655]
# action: [5 5 5 4 5 4 5 5]
# old probs updated: [0.51663345 0.51663345 0.51663345 0.48336655 0.51663345 0.48336655
#  0.51663345 0.51663345]
# old probs: [0.34657094 0.34657094 0.34657094 0.34657094 0.34657094 0.34657094
#  0.34657094 0.34657094]
# action: [5 4 5 4 4 5 4 5]
# old probs updated: [0.65342903 0.34657094 0.65342903 0.34657094 0.34657094 0.65342903
#  0.34657094 0.65342903]
# old probs: [0.39309582 0.39309582 0.39309582 0.39309582 0.39309582 0.39309582
#  0.39309582 0.39309582]
# action: [5 4 5 5 5 5 5 5]
# old probs updated: [0.60690415 0.39309582 0.60690415 0.60690415 0.60690415 0.60690415
#  0.60690415 0.60690415]
# old probs: [0.40494144 0.40494144 0.40494144 0.40494144 0.40494144 0.40494144
#  0.40494144 0.40494144]
# action: [5 5 4 5 5 4 5 5]
# old probs updated: [0.59505856 0.59505856 0.40494144 0.59505856 0.59505856 0.40494144
#  0.59505856 0.59505856]
# old probs: [0.49697477 0.49697477 0.49697477 0.49697477 0.49697477 0.49697477
#  0.49697477 0.49697477]
# action: [4 4 5 4 4 5 5 5]
# old probs updated: [0.49697477 0.49697477 0.50302523 0.49697477 0.49697477 0.50302523
#  0.50302523 0.50302523]
# old probs: [0.39784858 0.39784858 0.39784858 0.39784858 0.39784858 0.39784858
#  0.39784858 0.39784858]
# action: [5 5 4 5 5 4 5 4]
# old probs updated: [0.6021514  0.6021514  0.39784858 0.6021514  0.6021514  0.39784858
#  0.6021514  0.39784858]
# old probs: [0.4464156 0.4464156 0.4464156 0.4464156 0.4464156 0.4464156 0.4464156
#  0.4464156]
# action: [5 5 5 5 4 4 5 5]
# old probs updated: [0.5535844 0.5535844 0.5535844 0.5535844 0.4464156 0.4464156 0.5535844
#  0.5535844]
# old probs: [0.28496072 0.28496072 0.28496072 0.28496072 0.28496072 0.28496072
#  0.28496072 0.28496072]
# action: [5 5 5 5 4 5 5 5]
# old probs updated: [0.71503925 0.71503925 0.71503925 0.71503925 0.28496072 0.71503925
#  0.71503925 0.71503925]
# old probs: [0.4476557 0.4476557 0.4476557 0.4476557 0.4476557 0.4476557 0.4476557
#  0.4476557]
# action: [5 5 4 5 5 5 4 5]
# old probs updated: [0.5523443 0.5523443 0.4476557 0.5523443 0.5523443 0.5523443 0.4476557
#  0.5523443]
# old probs: [0.3798839 0.3798839 0.3798839 0.3798839 0.3798839 0.3798839 0.3798839
#  0.3798839]
# action: [5 4 5 5 5 4 4 4]
# old probs updated: [0.6201161 0.3798839 0.6201161 0.6201161 0.6201161 0.3798839 0.3798839
#  0.3798839]
# old probs: [0.39107677 0.39107677 0.39107677 0.39107677 0.39107677 0.39107677
#  0.39107677 0.39107677]
# action: [4 4 5 5 5 4 5 5]
# old probs updated: [0.39107677 0.39107677 0.6089232  0.6089232  0.6089232  0.39107677
#  0.6089232  0.6089232 ]
# old probs: [0.4017726 0.4017726 0.4017726 0.4017726 0.4017726 0.4017726 0.4017726
#  0.4017726]
# action: [4 4 5 4 5 5 4 5]
# old probs updated: [0.4017726 0.4017726 0.5982274 0.4017726 0.5982274 0.5982274 0.4017726
#  0.5982274]
# old probs: [0.3703793 0.3703793 0.3703793 0.3703793 0.3703793 0.3703793 0.3703793
#  0.3703793]
# action: [5 5 5 5 5 5 4 5]
# old probs updated: [0.6296207 0.6296207 0.6296207 0.6296207 0.6296207 0.6296207 0.3703793
#  0.6296207]
# old probs: [0.42117086 0.42117086 0.42117086 0.42117086 0.42117086 0.42117086
#  0.42117086 0.42117086]
# action: [5 5 5 4 5 5 5 4]
# old probs updated: [0.57882917 0.57882917 0.57882917 0.42117086 0.57882917 0.57882917
#  0.57882917 0.42117086]
# old probs: [0.35299838 0.35299838 0.35299838 0.35299838 0.35299838 0.35299838
#  0.35299838 0.35299838]
# action: [5 5 5 5 4 4 4 4]
# old probs updated: [0.6470016  0.6470016  0.6470016  0.6470016  0.35299838 0.35299838
#  0.35299838 0.35299838]
# old probs: [0.39409444 0.39409444 0.39409444 0.39409444 0.39409444 0.39409444
#  0.39409444 0.39409444]
# action: [5 5 5 4 4 5 4 4]
# old probs updated: [0.60590553 0.60590553 0.60590553 0.39409444 0.39409444 0.60590553
#  0.39409444 0.39409444]
# old probs: [0.316025 0.316025 0.316025 0.316025 0.316025 0.316025 0.316025 0.316025]
# action: [5 4 4 5 5 5 5 5]
# old probs updated: [0.683975 0.316025 0.316025 0.683975 0.683975 0.683975 0.683975 0.683975]
# old probs: [0.33808342 0.33808342 0.33808342 0.33808342 0.33808342 0.33808342
#  0.33808342 0.33808342]
# action: [4 5 4 5 5 5 4 5]
# old probs updated: [0.33808342 0.6619166  0.33808342 0.6619166  0.6619166  0.6619166
#  0.33808342 0.6619166 ]
# old probs: [0.34720737 0.34720737 0.34720737 0.34720737 0.34720737 0.34720737
#  0.34720737 0.34720737]
# action: [4 5 5 5 5 5 5 5]
# old probs updated: [0.34720737 0.65279263 0.65279263 0.65279263 0.65279263 0.65279263
#  0.65279263 0.65279263]
# old probs: [0.49962643 0.49962643 0.49962643 0.49962643 0.49962643 0.49962643
#  0.49962643 0.49962643]
# action: [4 4 5 4 5 5 4 5]
# old probs updated: [0.49962643 0.49962643 0.5003736  0.49962643 0.5003736  0.5003736
#  0.49962643 0.5003736 ]
# old probs: [0.49740595 0.49740595 0.49740595 0.49740595 0.49740595 0.49740595
#  0.49740595 0.49740595]
# action: [4 5 4 4 5 4 5 4]
# old probs updated: [0.49740595 0.50259405 0.49740595 0.49740595 0.50259405 0.49740595
#  0.50259405 0.49740595]
# old probs: [0.51251894 0.51251894 0.51251894 0.51251894 0.51251894 0.51251894
#  0.51251894 0.51251894]
# action: [4 5 4 4 5 4 4 5]
# old probs updated: [0.51251894 0.48748106 0.51251894 0.51251894 0.48748106 0.51251894
#  0.51251894 0.48748106]
# old probs: [0.5014544 0.5014544 0.5014544 0.5014544 0.5014544 0.5014544 0.5014544
#  0.5014544]
# action: [5 5 5 5 4 4 4 4]
# old probs updated: [0.4985456 0.4985456 0.4985456 0.4985456 0.5014544 0.5014544 0.5014544
#  0.5014544]
# old probs: [0.47655126 0.47655126 0.47655126 0.47655126 0.47655126 0.47655126
#  0.47655126 0.47655126]
# action: [5 5 5 4 5 4 4 4]
# old probs updated: [0.5234487  0.5234487  0.5234487  0.47655126 0.5234487  0.47655126
#  0.47655126 0.47655126]
# old probs: [0.46842593 0.46842593 0.46842593 0.46842593 0.46842593 0.46842593
#  0.46842593 0.46842593]
# action: [5 5 4 5 4 4 4 5]
# old probs updated: [0.5315741  0.5315741  0.46842593 0.5315741  0.46842593 0.46842593
#  0.46842593 0.5315741 ]
# old probs: [0.48526976 0.48526976 0.48526976 0.48526976 0.48526976 0.48526976
#  0.48526976 0.48526976]
# action: [4 5 5 4 5 5 5 5]
# old probs updated: [0.48526976 0.5147302  0.5147302  0.48526976 0.5147302  0.5147302
#  0.5147302  0.5147302 ]
# old probs: [0.49149328 0.49149328 0.49149328 0.49149328 0.49149328 0.49149328
#  0.49149328 0.49149328]
# action: [5 4 5 5 5 4 5 5]
# old probs updated: [0.5085067  0.49149328 0.5085067  0.5085067  0.5085067  0.49149328
#  0.5085067  0.5085067 ]
# old probs: [0.5015973 0.5015973 0.5015973 0.5015973 0.5015973 0.5015973 0.5015973
#  0.5015973]
# action: [5 4 4 5 4 4 5 4]
# old probs updated: [0.4984027 0.5015973 0.5015973 0.4984027 0.5015973 0.5015973 0.4984027
#  0.5015973]
# old probs: [0.48761213 0.48761213 0.48761213 0.48761213 0.48761213 0.48761213
#  0.48761213 0.48761213]
# action: [5 4 5 4 4 5 5 4]
# old probs updated: [0.5123879  0.48761213 0.5123879  0.48761213 0.48761213 0.5123879
#  0.5123879  0.48761213]
# old probs: [0.48317045 0.48317045 0.48317045 0.48317045 0.48317045 0.48317045
#  0.48317045 0.48317045]
# action: [4 4 5 4 4 5 4 4]
# old probs updated: [0.48317045 0.48317045 0.51682955 0.48317045 0.48317045 0.51682955
#  0.48317045 0.48317045]
# old probs: [0.4205199 0.4205199 0.4205199 0.4205199 0.4205199 0.4205199 0.4205199
#  0.4205199]
# action: [5 5 5 5 5 5 4 5]
# old probs updated: [0.5794801 0.5794801 0.5794801 0.5794801 0.5794801 0.5794801 0.4205199
#  0.5794801]
# old probs: [0.32404348 0.32404348 0.32404348 0.32404348 0.32404348 0.32404348
#  0.32404348 0.32404348]
# action: [4 5 5 4 5 5 4 5]
# old probs updated: [0.32404348 0.6759565  0.6759565  0.32404348 0.6759565  0.6759565
#  0.32404348 0.6759565 ]
# old probs: [0.43845734 0.43845734 0.43845734 0.43845734 0.43845734 0.43845734
#  0.43845734 0.43845734]
# action: [5 5 5 4 5 4 4 4]
# old probs updated: [0.56154263 0.56154263 0.56154263 0.43845734 0.56154263 0.43845734
#  0.43845734 0.43845734]
# old probs: [0.4824041 0.4824041 0.4824041 0.4824041 0.4824041 0.4824041 0.4824041
#  0.4824041]
# action: [5 5 5 5 5 4 4 4]
# old probs updated: [0.5175959 0.5175959 0.5175959 0.5175959 0.5175959 0.4824041 0.4824041
#  0.4824041]
# old probs: [0.37842488 0.37842488 0.37842488 0.37842488 0.37842488 0.37842488
#  0.37842488 0.37842488]
# action: [5 5 5 4 5 4 5 4]
# old probs updated: [0.6215751  0.6215751  0.6215751  0.37842488 0.6215751  0.37842488
#  0.6215751  0.37842488]
# old probs: [0.3557783 0.3557783 0.3557783 0.3557783 0.3557783 0.3557783 0.3557783
#  0.3557783]
# action: [5 5 5 5 4 4 4 4]
# old probs updated: [0.64422166 0.64422166 0.64422166 0.64422166 0.3557783  0.3557783
#  0.3557783  0.3557783 ]
# old probs: [0.50861615 0.50861615 0.50861615 0.50861615 0.50861615 0.50861615
#  0.50861615 0.50861615]
# action: [4 4 5 5 4 4 4 5]
# old probs updated: [0.50861615 0.50861615 0.49138385 0.49138385 0.50861615 0.50861615
#  0.50861615 0.49138385]
# old probs: [0.4709646 0.4709646 0.4709646 0.4709646 0.4709646 0.4709646 0.4709646
#  0.4709646]
# action: [4 4 4 5 4 4 4 5]
# old probs updated: [0.4709646 0.4709646 0.4709646 0.5290354 0.4709646 0.4709646 0.4709646
#  0.5290354]
# old probs: [0.46800756 0.46800756 0.46800756 0.46800756 0.46800756 0.46800756
#  0.46800756 0.46800756]
# action: [4 5 5 4 5 5 4 5]
# old probs updated: [0.46800756 0.53199244 0.53199244 0.46800756 0.53199244 0.53199244
#  0.46800756 0.53199244]
# old probs: [0.50346386 0.50346386 0.50346386 0.50346386 0.50346386 0.50346386
#  0.50346386 0.50346386]
# action: [5 5 4 5 5 4 4 4]
# old probs updated: [0.49653614 0.49653614 0.50346386 0.49653614 0.49653614 0.50346386
#  0.50346386 0.50346386]
# old probs: [0.49576855 0.49576855 0.49576855 0.49576855 0.49576855 0.49576855
#  0.49576855 0.49576855]
# action: [4 4 4 5 4 4 5 4]
# old probs updated: [0.49576855 0.49576855 0.49576855 0.50423145 0.49576855 0.49576855
#  0.50423145 0.49576855]
# old probs: [0.48194286 0.48194286 0.48194286 0.48194286 0.48194286 0.48194286
#  0.48194286 0.48194286]
# action: [4 4 4 4 4 5 4 5]
# old probs updated: [0.48194286 0.48194286 0.48194286 0.48194286 0.48194286 0.5180571
#  0.48194286 0.5180571 ]
# old probs: [0.4930014 0.4930014 0.4930014 0.4930014 0.4930014 0.4930014 0.4930014
#  0.4930014]
# action: [5 4 5 5 5 5 4 5]
# old probs updated: [0.5069986 0.4930014 0.5069986 0.5069986 0.5069986 0.5069986 0.4930014
#  0.5069986]
# old probs: [0.486779 0.486779 0.486779 0.486779 0.486779 0.486779 0.486779 0.486779]
# action: [5 5 4 4 4 5 5 5]
# old probs updated: [0.513221 0.513221 0.486779 0.486779 0.486779 0.513221 0.513221 0.513221]
# old probs: [0.48513263 0.48513263 0.48513263 0.48513263 0.48513263 0.48513263
#  0.48513263 0.48513263]
# action: [4 5 4 4 4 4 4 5]
# old probs updated: [0.48513263 0.51486737 0.48513263 0.48513263 0.48513263 0.48513263
#  0.48513263 0.51486737]
# old probs: [0.49139765 0.49139765 0.49139765 0.49139765 0.49139765 0.49139765
#  0.49139765 0.49139765]
# action: [4 5 5 5 5 5 4 4]
# old probs updated: [0.49139765 0.5086024  0.5086024  0.5086024  0.5086024  0.5086024
#  0.49139765 0.49139765]
# old probs: [0.4847455 0.4847455 0.4847455 0.4847455 0.4847455 0.4847455 0.4847455
#  0.4847455]
# action: [4 5 5 5 4 5 5 5]
# old probs updated: [0.4847455 0.5152545 0.5152545 0.5152545 0.4847455 0.5152545 0.5152545
#  0.5152545]
# old probs: [0.3801417  0.49584022 0.3801417  0.49584022 0.3801417  0.3801417
#  0.3801417  0.3801417 ]
# action: [5 5 4 5 5 5 4 5]
# old probs updated: [0.61985826 0.5041598  0.3801417  0.5041598  0.61985826 0.61985826
#  0.3801417  0.61985826]
# old probs: [0.38499612 0.4704033  0.38499612 0.4704033  0.38499612 0.38499612
#  0.38499612 0.38499612]
# action: [4 5 5 5 5 5 4 5]
# old probs updated: [0.38499612 0.5295967  0.6150039  0.5295967  0.6150039  0.6150039
#  0.38499612 0.6150039 ]
# old probs: [0.39341643 0.48623568 0.39341643 0.48623568 0.39341643 0.39341643
#  0.39341643 0.39341643]
# action: [4 5 4 5 5 5 4 4]
# old probs updated: [0.39341643 0.5137643  0.39341643 0.5137643  0.6065836  0.6065836
#  0.39341643 0.39341643]
# old probs: [0.3763726  0.48972586 0.3763726  0.48972586 0.3763726  0.3763726
#  0.3763726  0.3763726 ]
# action: [4 4 5 4 4 5 4 4]
# old probs updated: [0.3763726  0.48972586 0.6236274  0.48972586 0.3763726  0.6236274
#  0.3763726  0.3763726 ]
# old probs: [0.44942906 0.43728223 0.44942906 0.4869503  0.44942906 0.44942906
#  0.44942906 0.44942906]
# action: [5 5 4 4 4 4 5 5]
# old probs updated: [0.55057096 0.5627178  0.44942906 0.4869503  0.44942906 0.44942906
#  0.55057096 0.55057096]
# old probs: [0.34194782 0.44725165 0.34194782 0.4666051  0.34194782 0.34194782
#  0.34194782 0.34194782]
# action: [4 5 5 4 5 4 4 5]
# old probs updated: [0.34194782 0.5527483  0.6580522  0.4666051  0.6580522  0.34194782
#  0.34194782 0.6580522 ]
# old probs: [0.33520454 0.29442587 0.33520454 0.52751523 0.33520454 0.33520454
#  0.33520454 0.33520454]
# action: [5 5 5 5 4 4 4 5]
# old probs updated: [0.66479546 0.70557415 0.66479546 0.47248477 0.33520454 0.33520454
#  0.33520454 0.66479546]
# old probs: [0.492637   0.4782853  0.492637   0.42338115 0.492637   0.492637
#  0.492637   0.492637  ]
# action: [5 5 4 4 4 5 4 4]
# old probs updated: [0.50736296 0.5217147  0.492637   0.42338115 0.492637   0.50736296
#  0.492637   0.492637  ]
# old probs: [0.5025263  0.53480834 0.5025263  0.4018217  0.5025263  0.5025263
#  0.5025263  0.5025263 ]
# action: [5 5 5 4 4 4 5 4]
# old probs updated: [0.49747372 0.46519166 0.49747372 0.4018217  0.5025263  0.5025263
#  0.49747372 0.5025263 ]
# old probs: [0.49738932 0.4616087  0.49738932 0.7024988  0.49738932 0.49738932
#  0.49738932 0.49738932]
# action: [5 5 5 5 4 4 4 4]
# old probs updated: [0.5026107  0.5383913  0.5026107  0.2975012  0.49738932 0.49738932
#  0.49738932 0.49738932]
# old probs: [0.49069825 0.59436566 0.49069825 0.69006944 0.49069825 0.49069825
#  0.49069825 0.49069825]
# action: [4 5 5 4 4 5 4 5]
# old probs updated: [0.49069825 0.40563434 0.5093018  0.69006944 0.49069825 0.5093018
#  0.49069825 0.5093018 ]
# old probs: [0.48802936 0.4258475  0.48802936 0.4287996  0.48802936 0.48802936
#  0.48802936 0.48802936]
# action: [4 5 5 4 4 5 4 4]
# old probs updated: [0.48802936 0.57415247 0.51197064 0.4287996  0.48802936 0.51197064
#  0.48802936 0.48802936]
# old probs: [0.48665282 0.45452923 0.48665282 0.38752973 0.48665282 0.48665282
#  0.48665282 0.48665282]
# action: [4 4 4 5 5 5 5 5]
# old probs updated: [0.48665282 0.45452923 0.48665282 0.61247027 0.51334715 0.51334715
#  0.51334715 0.51334715]
# old probs: [0.48731515 0.3871079  0.48731515 0.24747124 0.48731515 0.48731515
#  0.48731515 0.48731515]
# action: [4 4 4 5 4 4 5 4]
# old probs updated: [0.48731515 0.3871079  0.48731515 0.7525288  0.48731515 0.48731515
#  0.5126848  0.48731515]
# old probs: [0.49237174 0.49237174 0.49237174 0.46166244 0.49237174 0.49237174
#  0.49237174 0.49237174]
# action: [5 4 4 4 5 4 5 5]
# old probs updated: [0.50762826 0.49237174 0.49237174 0.46166244 0.50762826 0.49237174
#  0.50762826 0.50762826]
# old probs: [0.4910028 0.4910028 0.4910028 0.4910028 0.4910028 0.4910028 0.4910028
#  0.4910028]
# action: [5 5 4 4 4 4 4 4]
# old probs updated: [0.5089972 0.5089972 0.4910028 0.4910028 0.4910028 0.4910028 0.4910028
#  0.4910028]
# old probs: [0.49326682 0.49326682 0.49326682 0.49326682 0.49326682 0.49326682
#  0.49326682 0.49326682]
# action: [4 4 4 5 5 4 4 4]
# old probs updated: [0.49326682 0.49326682 0.49326682 0.5067332  0.5067332  0.49326682
#  0.49326682 0.49326682]
# old probs: [0.4889883 0.4889883 0.4889883 0.4889883 0.4889883 0.4889883 0.4889883
#  0.4889883]
# action: [5 5 5 4 5 4 5 5]
# old probs updated: [0.5110117 0.5110117 0.5110117 0.4889883 0.5110117 0.4889883 0.5110117
#  0.5110117]
# old probs: [0.41225785 0.50255775 0.41225785 0.50255775 0.41225785 0.41225785
#  0.41225785 0.41225785]
# action: [4 5 4 5 5 5 5 4]
# old probs updated: [0.41225785 0.49744225 0.41225785 0.49744225 0.58774215 0.58774215
#  0.58774215 0.41225785]
# old probs: [0.35826808 0.31244156 0.35826808 0.49145454 0.35826808 0.35826808
#  0.35826808 0.35826808]
# action: [4 4 4 5 5 4 5 5]
# old probs updated: [0.35826808 0.31244156 0.35826808 0.50854546 0.6417319  0.35826808
#  0.6417319  0.6417319 ]
# old probs: [0.45044014 0.2978109  0.45044014 0.29401067 0.45044014 0.45044014
#  0.45044014 0.45044014]
# action: [5 5 5 5 5 4 5 4]
# old probs updated: [0.54955983 0.7021891  0.54955983 0.70598936 0.54955983 0.45044014
#  0.54955983 0.45044014]
# old probs: [0.53532255 0.47437155 0.53532255 0.30402082 0.53532255 0.53532255
#  0.53532255 0.53532255]
# action: [4 4 5 5 5 4 5 5]
# old probs updated: [0.53532255 0.47437155 0.46467745 0.6959792  0.46467745 0.53532255
#  0.46467745 0.46467745]
# old probs: [0.3734529  0.42470026 0.3734529  0.50337577 0.3734529  0.3734529
#  0.3734529  0.3734529 ]
# action: [5 4 5 4 5 4 5 5]
# old probs updated: [0.6265471  0.42470026 0.6265471  0.50337577 0.6265471  0.3734529
#  0.6265471  0.6265471 ]
# old probs: [0.34235933 0.51427126 0.34235933 0.4265725  0.34235933 0.34235933
#  0.34235933 0.34235933]
# action: [4 5 5 4 5 5 4 4]
# old probs updated: [0.34235933 0.48572874 0.6576407  0.4265725  0.6576407  0.6576407
#  0.34235933 0.34235933]
# old probs: [0.48424238 0.4492297  0.48424238 0.5516851  0.48424238 0.48424238
#  0.48424238 0.48424238]
# action: [4 5 5 5 5 4 4 4]
# old probs updated: [0.48424238 0.5507703  0.5157576  0.4483149  0.5157576  0.48424238
#  0.48424238 0.48424238]
# old probs: [0.47207052 0.47382173 0.47207052 0.3943531  0.47207052 0.47207052
#  0.47207052 0.47207052]
# action: [4 5 5 4 4 5 4 5]
# old probs updated: [0.47207052 0.52617824 0.5279295  0.3943531  0.47207052 0.5279295
#  0.47207052 0.5279295 ]
# old probs: [0.47113824 0.45471707 0.47113824 0.5503915  0.47113824 0.47113824
#  0.47113824 0.47113824]
# action: [4 5 5 5 5 5 5 4]
# old probs updated: [0.47113824 0.54528296 0.52886176 0.4496085  0.52886176 0.52886176
#  0.52886176 0.47113824]
# old probs: [0.4922007 0.5331778 0.4922007 0.5609911 0.4922007 0.4922007 0.4922007
#  0.4922007]
# action: [5 4 4 5 4 4 4 4]
# old probs updated: [0.50779927 0.5331778  0.4922007  0.4390089  0.4922007  0.4922007
#  0.4922007  0.4922007 ]
# old probs: [0.49103993 0.3547118  0.49103993 0.4663787  0.49103993 0.49103993
#  0.49103993 0.49103993]
# action: [4 5 4 5 4 5 4 5]
# old probs updated: [0.49103993 0.6452882  0.49103993 0.5336213  0.49103993 0.50896007
#  0.49103993 0.50896007]
# old probs: [0.49033168 0.46364057 0.49033168 0.47951323 0.49033168 0.49033168
#  0.49033168 0.49033168]
# action: [4 5 5 5 4 4 5 4]
# old probs updated: [0.49033168 0.5363594  0.50966835 0.5204868  0.49033168 0.49033168
#  0.50966835 0.49033168]
# old probs: [0.4946734 0.4946734 0.4946734 0.3415581 0.4946734 0.4946734 0.4946734
#  0.4946734]
# action: [5 5 4 4 4 5 5 4]
# old probs updated: [0.5053266 0.5053266 0.4946734 0.3415581 0.4946734 0.5053266 0.5053266
#  0.4946734]
# old probs: [0.4923804 0.4923804 0.4923804 0.4923804 0.4923804 0.4923804 0.4923804
#  0.4923804]
# action: [5 5 4 5 4 5 4 4]
# old probs updated: [0.5076196 0.5076196 0.4923804 0.5076196 0.4923804 0.5076196 0.4923804
#  0.4923804]
# old probs: [0.49201444 0.49201444 0.49201444 0.49201444 0.49201444 0.49201444
#  0.49201444 0.49201444]
# action: [5 4 5 5 5 4 5 4]
# old probs updated: [0.5079856  0.49201444 0.5079856  0.5079856  0.5079856  0.49201444
#  0.5079856  0.49201444]
# old probs: [0.49761555 0.49761555 0.49761555 0.49761555 0.49761555 0.49761555
#  0.49761555 0.49761555]
# action: [5 4 5 5 4 5 5 4]
# old probs updated: [0.5023844  0.49761555 0.5023844  0.5023844  0.49761555 0.5023844
#  0.5023844  0.49761555]
# old probs: [0.4822853 0.4822853 0.4822853 0.4822853 0.4822853 0.4822853 0.4822853
#  0.4822853]
# action: [5 5 5 4 4 4 5 5]
# old probs updated: [0.51771474 0.51771474 0.51771474 0.4822853  0.4822853  0.4822853
#  0.51771474 0.51771474]
# old probs: [0.36917284 0.50396234 0.36917284 0.50396234 0.36917284 0.36917284
#  0.36917284 0.36917284]
# action: [5 5 5 5 5 4 5 4]
# old probs updated: [0.6308272  0.49603766 0.6308272  0.49603766 0.6308272  0.36917284
#  0.6308272  0.36917284]
# old probs: [0.3761108  0.34002236 0.3761108  0.4789837  0.3761108  0.3761108
#  0.3761108  0.3761108 ]
# action: [4 5 5 5 5 4 5 5]
# old probs updated: [0.3761108 0.6599777 0.6238892 0.5210163 0.6238892 0.3761108 0.6238892
#  0.6238892]
# old probs: [0.44003388 0.24409637 0.44003388 0.336612   0.44003388 0.44003388
#  0.44003388 0.44003388]
# action: [4 5 4 4 4 4 5 5]
# old probs updated: [0.44003388 0.7559036  0.44003388 0.336612   0.44003388 0.44003388
#  0.5599661  0.5599661 ]
# old probs: [0.4063454  0.40493605 0.4063454  0.24181119 0.4063454  0.4063454
#  0.4063454  0.4063454 ]
# action: [5 4 4 5 4 5 4 5]
# old probs updated: [0.59365463 0.40493605 0.4063454  0.75818884 0.4063454  0.59365463
#  0.4063454  0.59365463]
# old probs: [0.47796103 0.40417185 0.47796103 0.39339188 0.47796103 0.47796103
#  0.47796103 0.47796103]
# action: [5 5 4 4 4 5 5 5]
# old probs updated: [0.52203894 0.5958282  0.47796103 0.39339188 0.47796103 0.52203894
#  0.52203894 0.52203894]
# old probs: [0.33550423 0.47519004 0.33550423 0.42203164 0.33550423 0.33550423
#  0.33550423 0.33550423]
# action: [5 5 5 4 5 5 5 4]
# old probs updated: [0.66449577 0.52480996 0.66449577 0.42203164 0.66449577 0.66449577
#  0.66449577 0.33550423]
# old probs: [0.32960063 0.5454277  0.32960063 0.52307415 0.32960063 0.32960063
#  0.32960063 0.32960063]
# action: [5 5 4 5 5 5 5 5]
# old probs updated: [0.67039937 0.45457232 0.32960063 0.47692585 0.67039937 0.67039937
#  0.67039937 0.67039937]
# old probs: [0.4993219  0.4666023  0.4993219  0.50552475 0.4993219  0.4993219
#  0.4993219  0.4993219 ]
# action: [4 5 5 4 5 4 4 5]
# old probs updated: [0.4993219  0.5333977  0.50067806 0.50552475 0.50067806 0.4993219
#  0.4993219  0.50067806]
# old probs: [0.49951935 0.51227903 0.49951935 0.41090482 0.49951935 0.49951935
#  0.49951935 0.49951935]
# action: [4 5 5 5 5 5 5 4]
# old probs updated: [0.49951935 0.48772097 0.50048065 0.5890952  0.50048065 0.50048065
#  0.50048065 0.49951935]
# old probs: [0.4968413 0.6038319 0.4968413 0.664108  0.4968413 0.4968413 0.4968413
#  0.4968413]
# action: [4 5 4 4 5 4 4 5]
# old probs updated: [0.4968413 0.3961681 0.4968413 0.664108  0.5031587 0.4968413 0.4968413
#  0.5031587]
# old probs: [0.48909932 0.5813199  0.48909932 0.6131194  0.48909932 0.48909932
#  0.48909932 0.48909932]
# action: [4 5 4 4 4 4 5 4]
# old probs updated: [0.48909932 0.41868007 0.48909932 0.6131194  0.48909932 0.48909932
#  0.5109007  0.48909932]
# old probs: [0.48014063 0.45608595 0.48014063 0.44448957 0.48014063 0.48014063
#  0.48014063 0.48014063]
# action: [5 5 5 5 4 5 5 4]
# old probs updated: [0.5198594  0.5439141  0.5198594  0.5555104  0.48014063 0.5198594
#  0.5198594  0.48014063]
# old probs: [0.47496653 0.30648676 0.47496653 0.5713331  0.47496653 0.47496653
#  0.47496653 0.47496653]
# action: [4 5 5 5 5 4 4 4]
# old probs updated: [0.47496653 0.6935133  0.5250335  0.4286669  0.5250335  0.47496653
#  0.47496653 0.47496653]
# old probs: [0.48299494 0.48299494 0.48299494 0.22099158 0.48299494 0.48299494
#  0.48299494 0.48299494]
# action: [5 4 4 5 4 4 4 5]
# old probs updated: [0.5170051  0.48299494 0.48299494 0.7790084  0.48299494 0.48299494
#  0.48299494 0.5170051 ]
# old probs: [0.48094732 0.48094732 0.48094732 0.48094732 0.48094732 0.48094732
#  0.48094732 0.48094732]
# action: [5 5 4 4 5 5 4 5]
# old probs updated: [0.5190527  0.5190527  0.48094732 0.48094732 0.5190527  0.5190527
#  0.48094732 0.5190527 ]
# old probs: [0.48910895 0.48910895 0.48910895 0.48910895 0.48910895 0.48910895
#  0.48910895 0.48910895]
# action: [5 4 4 5 4 4 4 5]
# old probs updated: [0.5108911  0.48910895 0.48910895 0.5108911  0.48910895 0.48910895
#  0.48910895 0.5108911 ]
# old probs: [0.48723558 0.48723558 0.48723558 0.48723558 0.48723558 0.48723558
#  0.48723558 0.48723558]
# action: [5 5 4 5 4 5 5 4]
# old probs updated: [0.51276445 0.51276445 0.48723558 0.51276445 0.48723558 0.51276445
#  0.51276445 0.48723558]
# old probs: [0.4895778 0.4895778 0.4895778 0.4895778 0.4895778 0.4895778 0.4895778
#  0.4895778]
# action: [5 5 4 5 4 4 5 5]
# old probs updated: [0.5104222 0.5104222 0.4895778 0.5104222 0.4895778 0.4895778 0.5104222
#  0.5104222]
# old probs: [0.4045633  0.49555376 0.4045633  0.49555376 0.4045633  0.4045633
#  0.4045633  0.4045633 ]
# action: [4 4 5 4 5 4 4 4]
# old probs updated: [0.4045633  0.49555376 0.5954367  0.49555376 0.5954367  0.4045633
#  0.4045633  0.4045633 ]
# old probs: [0.3601555  0.30319393 0.3601555  0.4878319  0.3601555  0.3601555
#  0.3601555  0.3601555 ]
# action: [5 5 4 4 5 5 5 5]
# old probs updated: [0.63984454 0.6968061  0.3601555  0.4878319  0.63984454 0.63984454
#  0.63984454 0.63984454]
# old probs: [0.4467791  0.28341565 0.4467791  0.285112   0.4467791  0.4467791
#  0.4467791  0.4467791 ]
# action: [5 5 5 5 4 5 4 5]
# old probs updated: [0.55322087 0.7165843  0.55322087 0.714888   0.4467791  0.55322087
#  0.4467791  0.55322087]
# old probs: [0.5358166  0.48277014 0.5358166  0.29891673 0.5358166  0.5358166
#  0.5358166  0.5358166 ]
# action: [4 5 5 5 4 5 5 4]
# old probs updated: [0.5358166  0.51722986 0.4641834  0.7010833  0.5358166  0.4641834
#  0.4641834  0.5358166 ]
# old probs: [0.37509087 0.42571747 0.37509087 0.5092986  0.37509087 0.37509087
#  0.37509087 0.37509087]
# action: [4 4 4 4 5 5 4 4]
# old probs updated: [0.37509087 0.42571747 0.37509087 0.5092986  0.62490916 0.62490916
#  0.37509087 0.37509087]
# old probs: [0.34733754 0.51735014 0.34733754 0.42939642 0.34733754 0.34733754
#  0.34733754 0.34733754]
# action: [4 4 4 4 4 4 5 5]
# old probs updated: [0.34733754 0.51735014 0.34733754 0.42939642 0.34733754 0.34733754
#  0.65266246 0.65266246]
# old probs: [0.48755533 0.44736734 0.48755533 0.54867977 0.48755533 0.48755533
#  0.48755533 0.48755533]
# action: [5 5 5 5 4 4 4 5]
# old probs updated: [0.5124447  0.5526327  0.5124447  0.45132023 0.48755533 0.48755533
#  0.48755533 0.5124447 ]
# old probs: [0.4710055  0.47059023 0.4710055  0.38955906 0.4710055  0.4710055
#  0.4710055  0.4710055 ]
# action: [4 4 5 5 4 4 4 4]
# old probs updated: [0.4710055  0.47059023 0.5289945  0.61044097 0.4710055  0.4710055
#  0.4710055  0.4710055 ]
# old probs: [0.47083488 0.4557169  0.47083488 0.5451103  0.47083488 0.47083488
#  0.47083488 0.47083488]
# action: [5 5 5 4 4 4 5 5]
# old probs updated: [0.52916515 0.5442831  0.52916515 0.5451103  0.47083488 0.47083488
#  0.52916515 0.52916515]
# old probs: [0.49287823 0.53381735 0.49287823 0.5756314  0.49287823 0.49287823
#  0.49287823 0.49287823]
# action: [4 5 4 4 5 5 5 5]
# old probs updated: [0.49287823 0.46618265 0.49287823 0.5756314  0.5071218  0.5071218
#  0.5071218  0.5071218 ]
# old probs: [0.49012226 0.36742824 0.49012226 0.48709574 0.49012226 0.49012226
#  0.49012226 0.49012226]
# action: [4 5 4 5 4 5 4 5]
# old probs updated: [0.49012226 0.63257176 0.49012226 0.5129043  0.49012226 0.50987774
#  0.49012226 0.50987774]
# old probs: [0.49016    0.47479308 0.49016    0.48958796 0.49016    0.49016
#  0.49016    0.49016   ]
# action: [4 5 5 4 4 5 5 5]
# old probs updated: [0.49016    0.5252069  0.50984    0.48958796 0.49016    0.50984
#  0.50984    0.50984   ]
# old probs: [0.5022031  0.5022031  0.5022031  0.34479776 0.5022031  0.5022031
#  0.5022031  0.5022031 ]
# action: [4 4 5 5 5 4 4 4]
# old probs updated: [0.5022031  0.5022031  0.4977969  0.65520227 0.4977969  0.5022031
#  0.5022031  0.5022031 ]
# old probs: [0.4853833 0.4853833 0.4853833 0.4853833 0.4853833 0.4853833 0.4853833
#  0.4853833]
# action: [4 4 5 4 5 4 4 5]
# old probs updated: [0.4853833 0.4853833 0.5146167 0.4853833 0.5146167 0.4853833 0.4853833
#  0.5146167]
# old probs: [0.4911073 0.4911073 0.4911073 0.4911073 0.4911073 0.4911073 0.4911073
#  0.4911073]
# action: [4 5 4 5 5 5 5 4]
# old probs updated: [0.4911073  0.50889266 0.4911073  0.50889266 0.50889266 0.50889266
#  0.50889266 0.4911073 ]
# old probs: [0.49678427 0.49678427 0.49678427 0.49678427 0.49678427 0.49678427
#  0.49678427 0.49678427]
# action: [5 5 4 4 4 5 4 5]
# old probs updated: [0.50321573 0.50321573 0.49678427 0.49678427 0.49678427 0.50321573
#  0.49678427 0.50321573]
# old probs: [0.48077774 0.48077774 0.48077774 0.48077774 0.48077774 0.48077774
#  0.48077774 0.48077774]
# action: [5 5 5 4 5 4 5 5]
# old probs updated: [0.51922226 0.51922226 0.51922226 0.48077774 0.51922226 0.48077774
#  0.51922226 0.51922226]
# old probs: [0.36616316 0.4996337  0.36616316 0.4996337  0.36616316 0.36616316
#  0.36616316 0.36616316]
# action: [5 4 4 4 5 5 5 5]
# old probs updated: [0.63383687 0.4996337  0.36616316 0.4996337  0.63383687 0.63383687
#  0.63383687 0.63383687]
# old probs: [0.37468573 0.3472107  0.37468573 0.47701237 0.37468573 0.37468573
#  0.37468573 0.37468573]
# action: [4 5 5 4 5 5 5 5]
# old probs updated: [0.37468573 0.6527893  0.62531424 0.47701237 0.62531424 0.62531424
#  0.62531424 0.62531424]
# old probs: [0.43682858 0.2525533  0.43682858 0.3480574  0.43682858 0.43682858
#  0.43682858 0.43682858]
# action: [5 4 4 5 4 5 4 4]
# old probs updated: [0.5631714  0.2525533  0.43682858 0.6519426  0.43682858 0.5631714
#  0.43682858 0.43682858]
# old probs: [0.411265   0.4089835  0.411265   0.23967512 0.411265   0.411265
#  0.411265   0.411265  ]
# action: [4 5 4 4 5 4 4 5]
# old probs updated: [0.411265   0.59101653 0.411265   0.23967512 0.588735   0.411265
#  0.411265   0.588735  ]
# old probs: [0.47582757 0.39173973 0.47582757 0.3945192  0.47582757 0.47582757
#  0.47582757 0.47582757]
# action: [4 5 5 4 5 4 4 5]
# old probs updated: [0.47582757 0.6082603  0.5241724  0.3945192  0.5241724  0.47582757
#  0.47582757 0.5241724 ]
# old probs: [0.33358154 0.47318956 0.33358154 0.42406914 0.33358154 0.33358154
#  0.33358154 0.33358154]
# action: [4 5 5 4 4 4 5 5]
# old probs updated: [0.33358154 0.5268104  0.66641843 0.42406914 0.33358154 0.33358154
#  0.66641843 0.66641843]
# old probs: [0.32921165 0.5500814  0.32921165 0.52310574 0.32921165 0.32921165
#  0.32921165 0.32921165]
# action: [4 4 5 4 5 5 5 5]
# old probs updated: [0.32921165 0.5500814  0.67078835 0.52310574 0.67078835 0.67078835
#  0.67078835 0.67078835]
# old probs: [0.5004066 0.4695495 0.5004066 0.5047351 0.5004066 0.5004066 0.5004066
#  0.5004066]
# action: [5 4 5 4 4 4 5 4]
# old probs updated: [0.49959338 0.4695495  0.49959338 0.5047351  0.5004066  0.5004066
#  0.49959338 0.5004066 ]
# old probs: [0.5050591  0.5088583  0.5050591  0.40723097 0.5050591  0.5050591
#  0.5050591  0.5050591 ]
# action: [4 5 5 5 5 5 4 5]
# old probs updated: [0.5050591  0.49114168 0.49494088 0.592769   0.49494088 0.49494088
#  0.5050591  0.49494088]
# old probs: [0.4987876  0.60545623 0.4987876  0.6670819  0.4987876  0.4987876
#  0.4987876  0.4987876 ]
# action: [5 5 4 4 5 5 5 5]
# old probs updated: [0.50121236 0.39454377 0.4987876  0.6670819  0.50121236 0.50121236
#  0.50121236 0.50121236]
# old probs: [0.49354178 0.6020714  0.49354178 0.6370186  0.49354178 0.49354178
#  0.49354178 0.49354178]
# action: [5 4 4 4 5 4 4 4]
# old probs updated: [0.5064582  0.6020714  0.49354178 0.6370186  0.5064582  0.49354178
#  0.49354178 0.49354178]
# old probs: [0.4902583  0.48036602 0.4902583  0.4745052  0.4902583  0.4902583
#  0.4902583  0.4902583 ]
# action: [4 4 4 5 5 4 4 4]
# old probs updated: [0.4902583  0.48036602 0.4902583  0.5254948  0.50974166 0.4902583
#  0.4902583  0.4902583 ]
# old probs: [0.47951695 0.31209567 0.47951695 0.59647095 0.47951695 0.47951695
#  0.47951695 0.47951695]
# action: [5 5 5 5 4 5 4 4]
# old probs updated: [0.520483   0.68790436 0.520483   0.40352905 0.47951695 0.520483
#  0.47951695 0.47951695]
# old probs: [0.48922294 0.48922294 0.48922294 0.230286   0.48922294 0.48922294
#  0.48922294 0.48922294]
# action: [4 4 5 5 4 5 5 4]
# old probs updated: [0.48922294 0.48922294 0.51077706 0.769714   0.48922294 0.51077706
#  0.51077706 0.48922294]
# old probs: [0.48621106 0.48621106 0.48621106 0.48621106 0.48621106 0.48621106
#  0.48621106 0.48621106]
# action: [4 4 5 4 4 5 5 5]
# old probs updated: [0.48621106 0.48621106 0.51378894 0.48621106 0.48621106 0.51378894
#  0.51378894 0.51378894]
# old probs: [0.4906426 0.4906426 0.4906426 0.4906426 0.4906426 0.4906426 0.4906426
#  0.4906426]
# action: [5 5 5 4 4 4 5 4]
# old probs updated: [0.5093574 0.5093574 0.5093574 0.4906426 0.4906426 0.4906426 0.5093574
#  0.4906426]
# old probs: [0.48958367 0.48958367 0.48958367 0.48958367 0.48958367 0.48958367
#  0.48958367 0.48958367]
# action: [4 4 5 4 4 4 4 4]
# old probs updated: [0.48958367 0.48958367 0.5104163  0.48958367 0.48958367 0.48958367
#  0.48958367 0.48958367]
# old probs: [0.48739046 0.48739046 0.48739046 0.48739046 0.48739046 0.48739046
#  0.48739046 0.48739046]
# action: [4 4 5 5 5 4 4 5]
# old probs updated: [0.48739046 0.48739046 0.51260954 0.51260954 0.51260954 0.48739046
#  0.48739046 0.51260954]
# old probs: [0.40491098 0.5052726  0.40491098 0.5052726  0.40491098 0.40491098
#  0.40491098 0.40491098]
# action: [4 5 5 5 5 5 5 5]
# old probs updated: [0.40491098 0.49472737 0.595089   0.49472737 0.595089   0.595089
#  0.595089   0.595089  ]
# old probs: [0.36181918 0.3219955  0.36181918 0.49114054 0.36181918 0.36181918
#  0.36181918 0.36181918]
# action: [5 5 5 5 5 5 4 5]
# old probs updated: [0.63818085 0.6780045  0.63818085 0.50885946 0.63818085 0.63818085
#  0.36181918 0.63818085]
# old probs: [0.4545254  0.2917002  0.4545254  0.29590788 0.4545254  0.4545254
#  0.4545254  0.4545254 ]
# action: [4 4 4 5 5 4 4 5]
# old probs updated: [0.4545254  0.2917002  0.4545254  0.70409214 0.5454746  0.4545254
#  0.4545254  0.5454746 ]
# old probs: [0.53209037 0.480469   0.53209037 0.29911005 0.53209037 0.53209037
#  0.53209037 0.53209037]
# action: [5 4 5 5 4 5 5 5]
# old probs updated: [0.46790963 0.480469   0.46790963 0.70088995 0.53209037 0.46790963
#  0.46790963 0.46790963]
# old probs: [0.37497798 0.42622668 0.37497798 0.50808287 0.37497798 0.37497798
#  0.37497798 0.37497798]
# action: [4 5 5 4 4 5 5 5]
# old probs updated: [0.37497798 0.5737733  0.62502205 0.50808287 0.37497798 0.62502205
#  0.62502205 0.62502205]
# old probs: [0.34592918 0.5199265  0.34592918 0.43034464 0.34592918 0.34592918
#  0.34592918 0.34592918]
# action: [5 5 5 4 5 5 5 4]
# old probs updated: [0.65407085 0.4800735  0.65407085 0.43034464 0.65407085 0.65407085
#  0.65407085 0.34592918]
# old probs: [0.4869282  0.45114923 0.4869282  0.54759544 0.4869282  0.4869282
#  0.4869282  0.4869282 ]
# action: [5 4 4 5 5 4 4 5]
# old probs updated: [0.5130718  0.45114923 0.4869282  0.45240456 0.5130718  0.4869282
#  0.4869282  0.5130718 ]
# old probs: [0.4709045  0.47204995 0.4709045  0.39017105 0.4709045  0.4709045
#  0.4709045  0.4709045 ]
# action: [5 4 4 4 4 4 5 5]
# old probs updated: [0.52909553 0.47204995 0.4709045  0.39017105 0.4709045  0.4709045
#  0.52909553 0.52909553]
# old probs: [0.47052413 0.46352938 0.47052413 0.5524275  0.47052413 0.47052413
#  0.47052413 0.47052413]
# action: [4 4 4 4 4 5 4 5]
# old probs updated: [0.47052413 0.46352938 0.47052413 0.5524275  0.47052413 0.52947587
#  0.47052413 0.52947587]
# old probs: [0.48921815 0.53577644 0.48921815 0.56837934 0.48921815 0.48921815
#  0.48921815 0.48921815]
# action: [5 4 5 4 4 4 5 4]
# old probs updated: [0.5107819  0.53577644 0.5107819  0.56837934 0.48921815 0.48921815
#  0.5107819  0.48921815]
# old probs: [0.48912424 0.41249225 0.48912424 0.47921562 0.48912424 0.48912424
#  0.48912424 0.48912424]
# action: [5 5 4 4 5 4 4 5]
# old probs updated: [0.51087576 0.5875077  0.48912424 0.47921562 0.51087576 0.48912424
#  0.48912424 0.51087576]
# old probs: [0.48463717 0.4763218  0.48463717 0.49119842 0.48463717 0.48463717
#  0.48463717 0.48463717]
# action: [5 4 4 5 4 4 4 4]
# old probs updated: [0.51536286 0.4763218  0.48463717 0.5088016  0.48463717 0.48463717
#  0.48463717 0.48463717]
# old probs: [0.4783797  0.4783797  0.4783797  0.47118488 0.4783797  0.4783797
#  0.4783797  0.4783797 ]
# action: [4 5 4 4 5 4 4 4]
# old probs updated: [0.4783797  0.5216203  0.4783797  0.47118488 0.5216203  0.4783797
#  0.4783797  0.4783797 ]
# old probs: [0.48027852 0.48027852 0.48027852 0.4704262  0.48027852 0.48027852
#  0.48027852 0.48027852]
# action: [4 5 5 5 5 4 5 5]
# old probs updated: [0.48027852 0.5197215  0.5197215  0.5295738  0.5197215  0.48027852
#  0.5197215  0.5197215 ]
# old probs: [0.4820167  0.4820167  0.4820167  0.33484563 0.4820167  0.4820167
#  0.4820167  0.4820167 ]
# action: [4 5 5 5 4 5 4 5]
# old probs updated: [0.4820167  0.5179833  0.5179833  0.66515434 0.4820167  0.5179833
#  0.4820167  0.5179833 ]
# old probs: [0.49044693 0.49044693 0.49044693 0.42981622 0.49044693 0.49044693
#  0.49044693 0.49044693]
# action: [5 4 5 5 4 5 5 4]
# old probs updated: [0.5095531  0.49044693 0.5095531  0.57018375 0.49044693 0.5095531
#  0.5095531  0.49044693]
# old probs: [0.4806063  0.4806063  0.4806063  0.26985988 0.4806063  0.4806063
#  0.4806063  0.4806063 ]
# action: [4 5 4 5 4 4 5 4]
# old probs updated: [0.4806063 0.5193937 0.4806063 0.7301401 0.4806063 0.4806063 0.5193937
#  0.4806063]
# old probs: [0.43423837 0.4958322  0.43423837 0.3944738  0.43423837 0.43423837
#  0.43423837 0.4958322 ]
# action: [4 5 4 5 5 5 5 4]
# old probs updated: [0.43423837 0.5041678  0.43423837 0.6055262  0.5657616  0.5657616
#  0.5657616  0.4958322 ]
# old probs: [0.38495222 0.33411303 0.38495222 0.4532789  0.38495222 0.38495222
#  0.38495222 0.4861518 ]
# action: [5 5 4 5 5 5 5 5]
# old probs updated: [0.6150478  0.665887   0.38495222 0.5467211  0.6150478  0.6150478
#  0.6150478  0.5138482 ]
# old probs: [0.42590684 0.21643776 0.42590684 0.40274546 0.42590684 0.42590684
#  0.42590684 0.49124503]
# action: [4 5 4 5 4 5 5 4]
# old probs updated: [0.42590684 0.78356224 0.42590684 0.5972545  0.42590684 0.57409316
#  0.57409316 0.49124503]
# old probs: [0.3991573  0.33310136 0.3991573  0.45356035 0.3991573  0.3991573
#  0.3991573  0.49085122]
# action: [5 5 5 5 5 5 5 4]
# old probs updated: [0.6008427  0.6668986  0.6008427  0.54643965 0.6008427  0.6008427
#  0.6008427  0.49085122]
# old probs: [0.48269168 0.39854324 0.48269168 0.40498906 0.48269168 0.48269168
#  0.48269168 0.48131174]
# action: [5 5 4 5 4 5 4 5]
# old probs updated: [0.51730835 0.60145676 0.48269168 0.59501094 0.48269168 0.51730835
#  0.48269168 0.51868826]
# old probs: [0.33262032 0.4728362  0.33262032 0.3714253  0.33262032 0.33262032
#  0.33262032 0.45966074]
# action: [5 4 4 4 5 5 5 4]
# old probs updated: [0.6673797  0.4728362  0.33262032 0.3714253  0.6673797  0.6673797
#  0.6673797  0.45966074]
# old probs: [0.32192588 0.53027254 0.32192588 0.41380808 0.32192588 0.32192588
#  0.32192588 0.53053325]
# action: [4 4 4 5 5 5 4 5]
# old probs updated: [0.32192588 0.53027254 0.32192588 0.5861919  0.6780741  0.6780741
#  0.32192588 0.46946675]
# old probs: [0.4874248  0.45155433 0.4874248  0.46347114 0.4874248  0.4874248
#  0.4874248  0.43484128]
# action: [4 5 5 4 5 4 5 5]
# old probs updated: [0.4874248  0.5484457  0.5125752  0.46347114 0.5125752  0.4874248
#  0.5125752  0.5651587 ]
# old probs: [0.5098151  0.5098968  0.5098151  0.31782955 0.5098151  0.5098151
#  0.5098151  0.37061182]
# action: [4 5 4 4 4 5 5 5]
# old probs updated: [0.5098151  0.4901032  0.5098151  0.31782955 0.5098151  0.4901849
#  0.4901849  0.6293882 ]
# old probs: [0.49510375 0.53137136 0.49510375 0.47330916 0.49510375 0.49510375
#  0.49510375 0.6401729 ]
# action: [5 4 5 5 4 4 4 4]
# old probs updated: [0.5048963  0.53137136 0.5048963  0.52669084 0.49510375 0.49510375
#  0.49510375 0.6401729 ]
# old probs: [0.4913424  0.52368224 0.4913424  0.57446617 0.4913424  0.4913424
#  0.4913424  0.59439284]
# action: [4 5 5 4 4 5 5 4]
# old probs updated: [0.4913424  0.47631776 0.5086576  0.57446617 0.4913424  0.5086576
#  0.5086576  0.59439284]
# old probs: [0.48320445 0.45678267 0.48320445 0.59291387 0.48320445 0.48320445
#  0.48320445 0.40250775]
# action: [4 5 5 4 4 4 4 4]
# old probs updated: [0.48320445 0.5432173  0.5167955  0.59291387 0.48320445 0.48320445
#  0.48320445 0.40250775]
# old probs: [0.49184147 0.42718348 0.49184147 0.25000328 0.49184147 0.49184147
#  0.49184147 0.49389163]
# action: [4 4 4 5 5 4 5 4]
# old probs updated: [0.49184147 0.42718348 0.49184147 0.7499967  0.50815856 0.49184147
#  0.50815856 0.49389163]
# old probs: [0.49499026 0.49499026 0.49499026 0.17617376 0.49499026 0.49499026
#  0.49499026 0.43911487]
# action: [5 4 5 5 4 4 4 5]
# old probs updated: [0.5050098  0.49499026 0.5050098  0.82382625 0.49499026 0.49499026
#  0.49499026 0.56088513]
# old probs: [0.48037687 0.48037687 0.48037687 0.6400937  0.48037687 0.48037687
#  0.48037687 0.47245917]
# action: [5 5 4 4 4 4 5 5]
# old probs updated: [0.51962316 0.51962316 0.48037687 0.6400937  0.48037687 0.48037687
#  0.51962316 0.5275408 ]
# old probs: [0.4862738  0.4862738  0.4862738  0.50047225 0.4862738  0.4862738
#  0.4862738  0.4862738 ]
# action: [5 4 5 4 5 4 5 5]
# old probs updated: [0.51372623 0.4862738  0.51372623 0.50047225 0.51372623 0.4862738
#  0.51372623 0.51372623]
# old probs: [0.4884396  0.4884396  0.4884396  0.4385241  0.4884396  0.4884396
#  0.46376252 0.4884396 ]
# action: [5 5 4 4 4 4 4 5]
# old probs updated: [0.51156044 0.51156044 0.4884396  0.4385241  0.4884396  0.4884396
#  0.46376252 0.51156044]
# old probs: [0.49361953 0.49361953 0.49361953 0.37795317 0.49361953 0.49361953
#  0.35331988 0.49361953]
# action: [4 4 4 5 4 4 4 4]
# old probs updated: [0.49361953 0.49361953 0.49361953 0.6220468  0.49361953 0.49361953
#  0.35331988 0.49361953]
# old probs: [0.3613628  0.4954578  0.3613628  0.47214362 0.3613628  0.4954578
#  0.3385407  0.4954578 ]
# action: [5 5 5 4 5 4 5 5]
# old probs updated: [0.6386372  0.50454223 0.6386372  0.47214362 0.6386372  0.4954578
#  0.6614593  0.50454223]
# old probs: [0.36256167 0.332668   0.36256167 0.43320188 0.36256167 0.49450782
#  0.3277612  0.49450782]
# action: [4 4 5 5 4 5 4 4]
# old probs updated: [0.36256167 0.332668   0.6374383  0.5667981  0.36256167 0.5054922
#  0.3277612  0.49450782]
# old probs: [0.44273704 0.31625125 0.44273704 0.529666   0.44273704 0.49667475
#  0.4153127  0.31535006]
# action: [4 5 4 4 4 4 5 5]
# old probs updated: [0.44273704 0.6837487  0.44273704 0.529666   0.44273704 0.49667475
#  0.5846873  0.68464994]
# old probs: [0.5461152  0.5073653  0.5461152  0.5859306  0.5461152  0.48717886
#  0.39781052 0.35037518]
# action: [5 4 4 5 4 5 4 5]
# old probs updated: [0.45388478 0.5073653  0.5461152  0.4140694  0.5461152  0.51282114
#  0.39781052 0.6496248 ]
# old probs: [0.35625878 0.41717747 0.35625878 0.5168599  0.35625878 0.48801506
#  0.4488058  0.5026761 ]
# action: [5 5 5 4 4 4 5 5]
# old probs updated: [0.64374125 0.58282256 0.64374125 0.5168599  0.35625878 0.48801506
#  0.5511942  0.49732387]
# old probs: [0.33595547 0.5218785  0.33595547 0.4255524  0.33595547 0.4913745
#  0.28998262 0.43130544]
# action: [5 4 4 5 5 5 5 5]
# old probs updated: [0.6640445  0.5218785  0.33595547 0.57444763 0.6640445  0.5086255
#  0.7100174  0.5686946 ]
# old probs: [0.46323144 0.44856793 0.46323144 0.4194304  0.46323144 0.4939481
#  0.45851696 0.5380206 ]
# action: [4 5 4 5 5 5 4 5]
# old probs updated: [0.46323144 0.5514321  0.46323144 0.5805696  0.53676856 0.5060519
#  0.45851696 0.4619794 ]
# old probs: [0.46935394 0.46812567 0.46935394 0.43087837 0.46935394 0.4916122
#  0.40326086 0.37550947]
# action: [4 4 4 4 4 5 5 5]
# old probs updated: [0.46935394 0.46812567 0.46935394 0.43087837 0.46935394 0.5083878
#  0.5967392  0.6244905 ]
# old probs: [0.4653915  0.4183091  0.4653915  0.5158665  0.4653915  0.48132548
#  0.6843224  0.49069577]
# action: [5 5 5 5 4 5 5 4]
# old probs updated: [0.5346085  0.5816909  0.5346085  0.48413348 0.4653915  0.5186745
#  0.31567758 0.49069577]
# old probs: [0.4881753  0.44949478 0.4881753  0.48826468 0.4881753  0.4881753
#  0.7042455  0.46223778]
# action: [5 5 4 4 4 5 4 4]
# old probs updated: [0.5118247  0.5505052  0.4881753  0.48826468 0.4881753  0.5118247
#  0.7042455  0.46223778]
# old probs: [0.4929198  0.42159697 0.4929198  0.47535053 0.4929198  0.4929198
#  0.4683471  0.49823314]
# action: [5 4 5 4 4 4 5 4]
# old probs updated: [0.5070802  0.42159697 0.5070802  0.47535053 0.4929198  0.4929198
#  0.5316529  0.49823314]
# old probs: [0.49138862 0.4743839  0.49138862 0.49138862 0.49138862 0.14434755
#  0.3582223  0.435709  ]
# action: [4 4 5 4 4 5 5 5]
# old probs updated: [0.49138862 0.4743839  0.5086114  0.49138862 0.49138862 0.85565245
#  0.6417777  0.564291  ]
# old probs: [0.48753867 0.48753867 0.48753867 0.48753867 0.48753867 0.3832068
#  0.40966338 0.47665042]
# action: [5 5 5 5 5 5 4 5]
# old probs updated: [0.5124613  0.5124613  0.5124613  0.5124613  0.5124613  0.61679316
#  0.40966338 0.5233496 ]
# old probs: [0.49525094 0.49525094 0.49525094 0.49525094 0.49525094 0.4234481
#  0.12129457 0.49525094]
# action: [4 5 4 4 5 5 5 5]
# old probs updated: [0.49525094 0.50474906 0.49525094 0.49525094 0.50474906 0.5765519
#  0.87870544 0.50474906]
# old probs: [0.48902816 0.48902816 0.48902816 0.33103013 0.48902816 0.44171533
#  0.5140692  0.48902816]
# action: [4 5 4 5 5 5 4 4]
# old probs updated: [0.48902816 0.51097184 0.48902816 0.66896987 0.51097184 0.55828464
#  0.5140692  0.48902816]
# old probs: [0.49714088 0.49714088 0.49714088 0.28374434 0.49714088 0.44341516
#  0.40522042 0.49714088]
# ...
#  0.46191412 0.510427  ]
# old probs: [0.49345753 0.4109584  0.4109584  0.49345753 0.49345753 0.49345753
#  0.4488598  0.42478865]
# action: [4 5 5 4 4 5 4 5]
# old probs updated: [0.49345753 0.5890416  0.5890416  0.49345753 0.49345753 0.50654244
#  0.4488598  0.57521135]
# old probs: [0.48718938 0.4715138  0.4715138  0.23880346 0.48718938 0.48718938
#  0.48718938 0.46939868]
# action: [4 5 4 5 5 5 5 5]
# old probs updated: [0.48718938 0.5284862  0.4715138  0.76119655 0.5128106  0.5128106
#  0.5128106  0.5306013 ]
# old probs: [0.48819116 0.48819116 0.48819116 0.27416068 0.48819116 0.48819116
#  0.274788   0.4861343 ]
# action: [5 5 4 5 4 4 4 5]
# old probs updated: [0.5118089  0.5118089  0.48819116 0.7258393  0.48819116 0.48819116
#  0.274788   0.5138657 ]
# old probs: [0.4828594  0.4828594  0.4828594  0.55275005 0.4828594  0.4828594
#  0.291661   0.4828594 ]
# action: [5 4 4 5 4 4 5 5]
# old probs updated: [0.5171406  0.4828594  0.4828594  0.44724995 0.4828594  0.4828594
#  0.708339   0.5171406 ]
# old probs: [0.47444355 0.47444355 0.47444355 0.44259843 0.47444355 0.47444355
#  0.50635916 0.47444355]
# action: [5 5 4 4 4 4 5 5]
# old probs updated: [0.52555645 0.52555645 0.47444355 0.44259843 0.47444355 0.47444355
#  0.49364084 0.52555645]
# old probs: [0.48509285 0.48509285 0.48509285 0.55620843 0.48509285 0.48509285
#  0.33547658 0.48509285]
# action: [5 5 5 5 4 4 5 5]
# old probs updated: [0.5149071  0.5149071  0.5149071  0.44379157 0.48509285 0.48509285
#  0.6645234  0.5149071 ]
# old probs: [0.4789377  0.4789377  0.4789377  0.39475647 0.4789377  0.4789377
#  0.4880103  0.4789377 ]
# action: [5 5 5 5 5 5 5 5]
# old probs updated: [0.5210623  0.5210623  0.5210623  0.60524356 0.5210623  0.5210623
#  0.5119897  0.5210623 ]
# old probs: [0.42630136 0.48981923 0.48981923 0.5241397  0.42630136 0.48981923
#  0.48295036 0.48981923]
# action: [4 4 5 5 4 5 4 5]
# old probs updated: [0.42630136 0.48981923 0.5101808  0.4758603  0.42630136 0.5101808
#  0.48295036 0.5101808 ]
# old probs: [0.36809358 0.33928004 0.33928004 0.46758443 0.36809358 0.43450376
#  0.52764046 0.4872283 ]
# action: [4 5 4 5 5 4 4 5]
# old probs updated: [0.36809358 0.66072    0.33928004 0.53241557 0.6319064  0.43450376
#  0.52764046 0.5127717 ]
# old probs: [0.425522   0.25819594 0.25819594 0.49667203 0.425522   0.42390034
#  0.45307684 0.34481487]
# action: [5 5 4 4 4 4 4 5]
# old probs updated: [0.57447803 0.74180406 0.25819594 0.49667203 0.425522   0.42390034
#  0.45307684 0.6551851 ]
# old probs: [0.4037036  0.40868726 0.40868726 0.4876118  0.4037036  0.44473267
#  0.50674015 0.24075596]
# action: [5 5 4 4 5 4 4 4]
# old probs updated: [0.5962964  0.59131277 0.40868726 0.4876118  0.5962964  0.44473267
#  0.50674015 0.24075596]
# old probs: [0.4853958  0.42787707 0.42787707 0.4804974  0.4853958  0.36281294
#  0.4855623  0.4290368 ]
# action: [4 5 5 5 5 5 5 5]
# old probs updated: [0.4853958  0.57212293 0.57212293 0.51950264 0.5146042  0.63718706
#  0.5144377  0.5709632 ]
# old probs: [0.29446986 0.48086438 0.48086438 0.49160805 0.29446986 0.50305325
#  0.4906475  0.41320115]
# action: [5 4 5 5 5 5 5 5]
# old probs updated: [0.70553017 0.48086438 0.5191356  0.508392   0.70553017 0.49694675
#  0.5093525  0.58679885]
# old probs: [0.2554722  0.5237801  0.5237801  0.49319443 0.2554722  0.6093096
#  0.49319443 0.50930685]
# action: [5 4 4 5 5 4 4 4]
# old probs updated: [0.7445278  0.5237801  0.5237801  0.50680554 0.7445278  0.6093096
#  0.49319443 0.50930685]
# old probs: [0.4713824  0.43453097 0.43453097 0.49263185 0.4713824  0.57729745
#  0.49263185 0.4772425 ]
# action: [5 4 4 5 4 5 4 4]
# old probs updated: [0.5286176  0.43453097 0.43453097 0.50736815 0.4713824  0.42270255
#  0.49263185 0.4772425 ]
# old probs: [0.4996008  0.5298725  0.5298725  0.49041677 0.4996008  0.40812105
#  0.49041677 0.39701906]
# action: [5 5 5 5 5 5 4 5]
# old probs updated: [0.50039923 0.47012752 0.47012752 0.50958323 0.50039923 0.59187895
#  0.49041677 0.602981  ]
# old probs: [0.48523653 0.5540294  0.5540294  0.48523653 0.48523653 0.49708974
#  0.48523653 0.64016736]
# action: [5 5 5 4 4 5 5 4]
# old probs updated: [0.5147635  0.4459706  0.4459706  0.48523653 0.48523653 0.50291026
#  0.5147635  0.64016736]
# old probs: [0.4903029  0.5119216  0.5119216  0.4903029  0.4903029  0.54200506
#  0.4903029  0.56122714]
# action: [4 4 4 4 5 5 4 4]
# old probs updated: [0.4903029  0.5119216  0.5119216  0.4903029  0.5096971  0.45799494
#  0.4903029  0.56122714]
# old probs: [0.48008084 0.5246335  0.5246335  0.24966083 0.48008084 0.4743375
#  0.48008084 0.47773805]
# action: [4 5 4 5 5 4 5 4]
# old probs updated: [0.48008084 0.47536647 0.5246335  0.75033915 0.51991916 0.4743375
#  0.51991916 0.47773805]
# old probs: [0.48581374 0.45671934 0.45671934 0.21505007 0.48581374 0.32932386
#  0.46085683 0.52804023]
# action: [5 5 4 5 5 5 5 4]
# old probs updated: [0.51418626 0.54328066 0.45671934 0.7849499  0.51418626 0.6706761
#  0.5391432  0.52804023]
# old probs: [0.49318957 0.49318957 0.49318957 0.4339081  0.49318957 0.21947944
#  0.19826494 0.46849263]
# action: [4 4 4 5 5 4 5 4]
# old probs updated: [0.49318957 0.49318957 0.49318957 0.5660919  0.5068104  0.21947944
#  0.80173504 0.46849263]
# old probs: [0.48257327 0.48257327 0.48257327 0.42371055 0.48257327 0.42791912
#  0.465138   0.48257327]
# action: [4 5 4 4 4 5 4 5]
# old probs updated: [0.48257327 0.5174267  0.48257327 0.42371055 0.48257327 0.57208085
#  0.465138   0.5174267 ]
# old probs: [0.48018295 0.48018295 0.48018295 0.5419778  0.48018295 0.46201965
#  0.38420862 0.48018295]
# action: [4 4 5 4 4 4 5 5]
# old probs updated: [0.48018295 0.48018295 0.51981705 0.5419778  0.48018295 0.46201965
#  0.6157914  0.51981705]
# old probs: [0.48466125 0.48466125 0.48466125 0.53955054 0.48466125 0.5403794
#  0.51370794 0.48466125]
# action: [5 4 4 5 4 4 4 4]
# old probs updated: [0.5153388  0.48466125 0.48466125 0.46044946 0.48466125 0.5403794
#  0.51370794 0.48466125]
# old probs: [0.4850164  0.4850164  0.4850164  0.44961876 0.4850164  0.501421
#  0.39415616 0.4850164 ]
# action: [5 4 5 5 4 4 5 4]
# old probs updated: [0.5149836  0.4850164  0.5149836  0.55038124 0.4850164  0.501421
#  0.60584384 0.4850164 ]
# old probs: [0.3625189  0.49766538 0.49766538 0.5898394  0.3625189  0.4054257
#  0.48651475 0.49766538]
# action: [5 4 5 4 4 5 4 4]
# old probs updated: [0.6374811  0.49766538 0.5023346  0.5898394  0.3625189  0.59457433
#  0.48651475 0.49766538]
# old probs: [0.36552128 0.34378004 0.34378004 0.48958465 0.36552128 0.52388144
#  0.50740016 0.48755035]
# action: [4 5 5 4 5 4 5 4]
# old probs updated: [0.36552128 0.65621996 0.65621996 0.48958465 0.6344787  0.52388144
#  0.49259984 0.48755035]
# old probs: [0.44274482 0.33045584 0.33045584 0.4682084  0.44274482 0.46379766
#  0.47029117 0.31534758]
# action: [4 5 4 5 5 4 5 4]
# old probs updated: [0.44274482 0.66954416 0.33045584 0.53179157 0.55725515 0.46379766
#  0.52970886 0.31534758]
# old probs: [0.5508604  0.4945564  0.4945564  0.49285907 0.5508604  0.4654658
#  0.49533767 0.33985323]
# action: [4 4 4 5 4 4 4 5]
# old probs updated: [0.5508604  0.4945564  0.4945564  0.50714093 0.5508604  0.4654658
#  0.49533767 0.6601468 ]
# old probs: [0.33320272 0.4187624  0.4187624  0.45513758 0.33320272 0.48487684
#  0.44212475 0.52170753]
# action: [4 5 4 5 5 5 4 4]
# old probs updated: [0.33320272 0.5812376  0.4187624  0.5448624  0.6667973  0.5151231
#  0.44212475 0.52170753]
# old probs: [0.3041079  0.51570916 0.51570916 0.4803399  0.3041079  0.45662656
#  0.47200623 0.4112529 ]
# action: [5 5 5 5 5 4 4 4]
# old probs updated: [0.6958921  0.48429084 0.48429084 0.5196601  0.6958921  0.45662656
#  0.47200623 0.4112529 ]
# old probs: [0.4661198  0.44517836 0.44517836 0.48215944 0.4661198  0.48215944
#  0.48215944 0.55136067]
# action: [5 5 4 5 4 5 5 5]
# old probs updated: [0.53388023 0.5548216  0.44517836 0.51784056 0.4661198  0.51784056
#  0.51784056 0.44863933]
# old probs: [0.4459401  0.46716017 0.46716017 0.4899438  0.4459401  0.4899438
#  0.4899438  0.35597816]
# action: [5 5 5 5 4 4 4 4]
# old probs updated: [0.55405986 0.53283983 0.53283983 0.5100562  0.4459401  0.4899438
#  0.4899438  0.35597816]
# old probs: [0.4721784  0.49253976 0.4103173  0.48231724 0.4721784  0.48231724
#  0.48231724 0.55311066]
# action: [4 5 5 4 4 4 4 5]
# old probs updated: [0.4721784  0.50746024 0.5896827  0.48231724 0.4721784  0.48231724
#  0.48231724 0.44688934]
# old probs: [0.48570448 0.4817214  0.4601023  0.48570448 0.48570448 0.48570448
#  0.48570448 0.5325109 ]
# action: [5 4 5 4 5 4 4 5]
# old probs updated: [0.5142955  0.4817214  0.5398977  0.48570448 0.5142955  0.48570448
#  0.48570448 0.46748912]
# old probs: [0.49140155 0.48111248 0.33739287 0.49140155 0.49140155 0.49140155
#  0.49140155 0.4843674 ]
# action: [4 4 5 5 4 4 4 5]
# old probs updated: [0.49140155 0.48111248 0.66260713 0.50859845 0.49140155 0.49140155
#  0.49140155 0.5156326 ]
# old probs: [0.48903504 0.4714002  0.4193722  0.25627884 0.48903504 0.48903504
#  0.48903504 0.46656567]
# action: [4 4 4 5 4 5 5 4]
# old probs updated: [0.48903504 0.4714002  0.4193722  0.7437211  0.48903504 0.510965
#  0.510965   0.46656567]
# old probs: [0.48612884 0.48612884 0.44899368 0.33616045 0.48612884 0.33347702
#  0.32635853 0.4850625 ]
# action: [5 4 5 5 5 4 5 4]
# old probs updated: [0.5138712  0.48612884 0.5510063  0.6638396  0.5138712  0.33347702
#  0.67364144 0.4850625 ]
# old probs: [0.48592857 0.48592857 0.44167888 0.51623183 0.48592857 0.35001174
#  0.32923844 0.48592857]
# action: [4 5 5 5 5 5 5 5]
# old probs updated: [0.48592857 0.51407146 0.5583211  0.48376817 0.51407146 0.6499883
#  0.6707616  0.51407146]
# old probs: [0.4737187  0.4737187  0.43749365 0.40497053 0.4737187  0.53532326
#  0.46861503 0.4737187 ]
# action: [5 5 5 5 4 4 4 5]
# old probs updated: [0.5262813  0.5262813  0.5625063  0.5950295  0.4737187  0.53532326
#  0.46861503 0.5262813 ]
# old probs: [0.48245    0.48245    0.38382867 0.49325615 0.48245    0.38853863
#  0.33041888 0.48245   ]
# action: [4 4 5 5 5 5 5 5]
# old probs updated: [0.48245    0.48245    0.61617136 0.50674385 0.51755    0.6114614
#  0.6695811  0.51755   ]
# old probs: [0.4813707  0.4813707  0.41727284 0.40734848 0.4813707  0.4976498
#  0.48153403 0.4813707 ]
# action: [4 5 4 5 4 5 4 4]
# old probs updated: [0.4813707  0.5186293  0.41727284 0.5926515  0.4813707  0.5023502
#  0.48153403 0.4813707 ]
# old probs: [0.42572093 0.48581553 0.56367373 0.51187277 0.42572093 0.3956286
#  0.46977675 0.48581553]
# action: [4 5 4 5 4 5 5 4]
# old probs updated: [0.42572093 0.5141845  0.56367373 0.48812723 0.42572093 0.6043714
#  0.53022325 0.48581553]
# old probs: [0.35502318 0.3351509  0.584345   0.45898303 0.35502318 0.52429765
#  0.50835097 0.48367915]
# action: [5 4 5 5 5 5 4 5]
# old probs updated: [0.64497685 0.3351509  0.41565502 0.54101694 0.64497685 0.47570235
#  0.50835097 0.5163208 ]
# old probs: [0.4227591  0.24635117 0.48930308 0.4970134  0.4227591  0.49191138
#  0.45275316 0.35034466]
# action: [4 5 4 5 5 4 4 4]
# old probs updated: [0.4227591  0.7536488  0.48930308 0.5029866  0.57724094 0.49191138
#  0.45275316 0.35034466]
# old probs: [0.39208376 0.40079293 0.41003278 0.49024296 0.39208376 0.5055509
#  0.5136756  0.23742138]
# action: [5 5 5 4 4 4 5 4]
# old probs updated: [0.60791624 0.59920704 0.58996725 0.49024296 0.39208376 0.5055509
#  0.48632443 0.23742138]
# old probs: [0.49534792 0.40689027 0.5640711  0.47617683 0.49534792 0.48618495
#  0.48730916 0.40203843]
# action: [5 4 4 4 5 4 4 5]
# old probs updated: [0.5046521  0.40689027 0.5640711  0.47617683 0.5046521  0.48618495
#  0.48730916 0.59796154]
# old probs: [0.2782696  0.4695418  0.5905246  0.4912119  0.2782696  0.48275235
#  0.49190977 0.4015803 ]
# action: [4 4 4 4 5 5 4 4]
# old probs updated: [0.2782696  0.4695418  0.5905246  0.4912119  0.7217304  0.5172477
#  0.49190977 0.4015803 ]
# old probs: [0.24566394 0.5244872  0.65218365 0.494745   0.24566394 0.494745
#  0.494745   0.4996513 ]
# action: [5 4 4 4 4 5 4 4]
# old probs updated: [0.75433606 0.5244872  0.65218365 0.494745   0.24566394 0.505255
#  0.494745   0.4996513 ]
# old probs: [0.49407983 0.44353393 0.55882823 0.49406284 0.49407983 0.49406284
#  0.49406284 0.5062463 ]
# action: [4 4 4 5 5 4 4 4]
# old probs updated: [0.49407983 0.44353393 0.55882823 0.50593716 0.5059202  0.49406284
#  0.49406284 0.5062463 ]
# old probs: [0.49811232 0.5341219  0.4971325  0.49179798 0.49811232 0.49179798
#  0.49179798 0.40865788]
# action: [5 4 4 5 5 4 5 5]
# old probs updated: [0.5018877  0.5341219  0.4971325  0.508202   0.5018877  0.49179798
#  0.508202   0.5913421 ]
# old probs: [0.49253824 0.55067635 0.469072   0.49253824 0.49253824 0.49253824
#  0.49253824 0.6296774 ]
# action: [5 4 5 5 5 5 4 4]
# old probs updated: [0.5074618  0.55067635 0.530928   0.5074618  0.5074618  0.5074618
#  0.49253824 0.6296774 ]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-9-f595ec5f4a7d> in <module>
#      34     # this is the SOLUTION!
#      35     # use your own surrogate function
# ---> 36     L = -surrogate(policy, old_probs, states, actions, rewards, beta=beta)
#      37
#      38     #L = -pong_utils.surrogate(policy, old_probs, states, actions, rewards, beta=beta)
#
# <ipython-input-8-adb2d9f7318c> in surrogate(policy, old_probs, states, actions, rewards, gamma, beta)
#      12
#      13     # convert states to policy (or probability)
# ---> 14     new_probs = pong_utils.states_to_prob(policy, states)
#      15     # debug
#      16     print(f'new probs: {new_probs}')
#
# c:\Workstation\software_projects\python\udacity_reinforcement_learning_course\deep-reinforcement-learning\pong_REINFORCE\pong_utils.py in states_to_prob(policy, states)
#     165     states = torch.stack(states)
#     166     policy_input = states.view(-1,*states.shape[-3:])
# --> 167     return policy(policy_input).view(states.shape[:-3])
#     168
#     169 # return sum of log-prob divided by T
#
# ~\Anaconda3\envs\ml\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# <ipython-input-4-796d6dea56c4> in forward(self, x)
#      49
#      50     def forward(self, x):
# ---> 51         x = self.convs(x)
#      52         x = x.view(-1, self.size)
#      53         return torch.sigmoid(self.fcs(x))
#
# ~\Anaconda3\envs\ml\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# ~\Anaconda3\envs\ml\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~\Anaconda3\envs\ml\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# ~\Anaconda3\envs\ml\lib\site-packages\torch\nn\modules\batchnorm.py in forward(self, input)
#      79             input, self.running_mean, self.running_var, self.weight, self.bias,
#      80             self.training or not self.track_running_stats,
# ---> 81             exponential_average_factor, self.eps)
#      82
#      83     def extra_repr(self):
#
# ~\Anaconda3\envs\ml\lib\site-packages\torch\nn\functional.py in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    1654     return torch.batch_norm(
#    1655         input, weight, bias, running_mean, running_var,
# -> 1656         training, momentum, eps, torch.backends.cudnn.enabled
#    1657     )
#    1658
#
# RuntimeError: CUDA out of memory. Tried to allocate 476.00 MiB (GPU 0; 2.00 GiB total capacity; 1.16 GiB already allocated; 106.46 MiB free; 26.10 MiB cached)

# %%
# play game after training!
pong_utils.play(env, policy, time=2000)

# %%
plt.plot(mean_rewards)

# %%
# save your policy!
torch.save(policy, 'REINFORCE.policy')

# load your policy if needed
# policy = torch.load('REINFORCE.policy')

# try and test out the solution!
# policy = torch.load('PPO_solution.policy')
